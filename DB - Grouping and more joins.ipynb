# %% [markdown]
# # Assignment 7: Grouping and more joins

# %% [markdown]
# Author: Danny Nielsen

# %% [markdown]
# ## 1) Using a single join and a grouping, write a query that allows you to find the `forename`, `surname`, `driverid` and the total number of wins for each driver in the `f1db` schema.

# %%
# %%sql SELECT forename, surname, drivers.driverid, count(*) AS no_wins FROM drivers
# JOIN results on results.driverid = drivers.driverid WHERE results.position = 1
# GROUP BY forename, surname, drivers.driverid ORDER BY count(*) DESC;
# Out:
# 107 rows affected.
# [('Michael', 'Schumacher', 30, 91),
#  ('Lewis', 'Hamilton', 1, 60),
#  ('Alain', 'Prost', 117, 51),
#  ('Sebastian', 'Vettel', 20, 46),
#  ('Ayrton', 'Senna', 102, 41),
#  ('Fernando', 'Alonso', 4, 32),
#  ('Nigel', 'Mansell', 95, 31),
#  ('Jackie', 'Stewart', 328, 27),
#  ('Jim', 'Clark', 373, 25),
#  ('Niki', 'Lauda', 182, 25),
#  ('Juan', 'Fangio', 579, 24),
#  ('Nico', 'Rosberg', 3, 23),
#  ('Nelson', 'Piquet', 137, 23),
#  ('Damon', 'Hill', 71, 22),
#  ('Mika', 'Häkkinen', 57, 20),
#  ('Kimi', 'Räikkönen', 8, 20),
#  ('Stirling', 'Moss', 475, 16),
#  ('Jenson', 'Button', 18, 15),
#  ('Graham', 'Hill', 289, 14),
#  ('Jack', 'Brabham', 356, 14),
#  ('Emerson', 'Fittipaldi', 224, 14),
#  ('Alberto', 'Ascari', 647, 13),
#  ('David', 'Coulthard', 14, 13),
#  ('Mario', 'Andretti', 207, 12),
#  ('Alan', 'Jones', 178, 12),
#  ('Carlos', 'Reutemann', 199, 12),
#  ('Jacques', 'Villeneuve', 35, 11),
#  ('Felipe', 'Massa', 13, 11),
#  ('Rubens', 'Barrichello', 22, 11),
#  ('Ronnie', 'Peterson', 238, 10),
#  ('Gerhard', 'Berger', 77, 10),
#  ('Jody', 'Scheckter', 222, 10),
#  ('James', 'Hunt', 231, 10),
#  ('Mark', 'Webber', 17, 9),
#  ('Denny', 'Hulme', 304, 8),
#  ('Jacky', 'Ickx', 235, 8),
#  ('Juan', 'Pablo Montoya', 31, 7),
#  ('René', 'Arnoux', 163, 7),
#  ('Gilles', 'Villeneuve', 203, 6),
#  ('John', 'Surtees', 341, 6),
#  ('Tony', 'Brooks', 479, 6),
#  ('Ralf', 'Schumacher', 23, 6),
#  ('Jochen', 'Rindt', 358, 6),
#  ('Riccardo', 'Patrese', 119, 6),
#  ('Jacques', 'Laffite', 172, 6),
#  ('Michele', 'Alboreto', 105, 5),
#  ('Daniel', 'Ricciardo', 817, 5),
#  ('Nino', 'Farina', 642, 5),
#  ('John', 'Watson', 187, 5),
#  ('Keke', 'Rosberg', 177, 5),
#  ('Clay', 'Regazzoni', 223, 5),
#  ('Eddie', 'Irvine', 56, 4),
#  ('Dan', 'Gurney', 364, 4),
#  ('Bruce', 'McLaren', 360, 4),
#  ('Johnny', 'Herbert', 65, 3),
#  ('Didier', 'Pironi', 202, 3),
#  ('Heinz-Harald', 'Frentzen', 49, 3),
#  ('Phil', 'Hill', 403, 3),
#  ('Mike', 'Hawthorn', 578, 3),
#  ('Thierry', 'Boutsen', 123, 3),
#  ('Peter', 'Collins', 581, 3),
#  ('Giancarlo', 'Fisichella', 21, 3),
#  ('Jean-Pierre', 'Jabouille', 219, 2),
#  ('José Froilán', 'González', 498, 2),
#  ('Wolfgang', 'von Trips', 476, 2),
#  ('Bill', 'Vukovich', 657, 2),
#  ('Pedro', 'Rodríguez', 345, 2),
#  ('Maurice', 'Trintignant', 427, 2),
#  ('Patrick', 'Tambay', 175, 2),
#  ('Jo', 'Siffert', 346, 2),
#  ('Valtteri', 'Bottas', 822, 2),
#  ('Max', 'Verstappen', 830, 2),
#  ('Elio', 'de Angelis', 173, 2),
#  ('Patrick', 'Depailler', 221, 2),
#  ('Peter', 'Revson', 309, 2),
#  ('Peter', 'Gethin', 320, 1),
#  ('Jo', 'Bonnier', 347, 1),
#  ('Jim', 'Rathmann', 509, 1),
#  ('Robert', 'Kubica', 9, 1),
#  ('Luigi', 'Fagioli', 786, 1),
#  ('Lorenzo', 'Bandini', 385, 1),
#  ('Lee', 'Wallard', 766, 1),
#  ('Heikki', 'Kovalainen', 5, 1),
#  ('Gunnar', 'Nilsson', 255, 1),
#  ('Jochen', 'Mass', 200, 1),
#  ('Jean', 'Alesi', 55, 1),
#  ('Jarno', 'Trulli', 15, 1),
#  ('Jean-Pierre', 'Beltoise', 306, 1),
#  ('Jimmy', 'Bryan', 525, 1),
#  ('Ludovico', 'Scarfiotti', 375, 1),
#  ('Luigi', 'Musso', 577, 1),
#  ('Richie', 'Ginther', 386, 1),
#  ('Bob', 'Sweikert', 628, 1),
#  ('Troy', 'Ruttman', 526, 1),
#  ('Innes', 'Ireland', 404, 1),
#  ('Pastor', 'Maldonado', 813, 1),
#  ('Johnnie', 'Parsons', 593, 1),
#  ('Olivier', 'Panis', 44, 1),
#  ('Rodger', 'Ward', 449, 1),
#  ('Piero', 'Taruffi', 641, 1),
#  ('François', 'Cevert', 327, 1),
#  ('Giancarlo', 'Baghetti', 394, 1),
#  ('Vittorio', 'Brambilla', 230, 1),
#  ('Carlos', 'Pace', 250, 1),
#  ('Sam', 'Hanks', 611, 1),
#  ('Pat', 'Flaherty', 559, 1),
#  ('Alessandro', 'Nannini', 145, 1)]

# %% [markdown]
# ## 2) Write a query that joins the tables results, constructors and drivers to show the amount of times a driver has driven a car from a constructor. (...) Your table should have three fields: `drivers.driverref`, `constructors.name` and `count(*)` (...)

# %%
# %%sql SELECT drivers.driverref, constructors.name, count(*) FROM drivers
# JOIN results on results.driverid = drivers.driverid
# JOIN constructors USING (constructorid)
# GROUP BY drivers.driverref, constructors.name ORDER BY count(*) DESC;
# Out:
# 2093 rows affected.
# [('michael_schumacher', 'Ferrari', 181),
#  ('coulthard', 'McLaren', 150),
#  ('massa', 'Ferrari', 140),
#  ('button', 'McLaren', 137),
#  ('rosberg', 'Mercedes', 136),
#  ('hakkinen', 'McLaren', 133),
#  ('laffite', 'Ligier', 132),
#  ('webber', 'Red Bull', 129),
#  ('raikkonen', 'Ferrari', 126),
#  ('vettel', 'Red Bull', 113),
#  ('hamilton', 'McLaren', 110),
#  ('prost', 'McLaren', 109),
#  ('martini', 'Minardi', 106),
#  ('alonso', 'Renault', 106),
#  ('barrichello', 'Ferrari', 104),
#  ('mansell', 'Williams', 97),
#  ('berger', 'Ferrari', 96),
#  ('senna', 'McLaren', 96),
#  ('alonso', 'Ferrari', 96),
#  ('ralf_schumacher', 'Williams', 94),
#  ('hamilton', 'Mercedes', 93),
#  ('piquet', 'Brabham', 92),
#  ('sutil', 'Force India', 92),
#  ('trulli', 'Toyota', 91),
#  ('angelis', 'Team Lotus', 91),
#  ('raikkonen', 'McLaren', 88),
#  ('villeneuve', 'BAR', 82),
#  ('patrese', 'Williams', 81),
#  ('alboreto', 'Ferrari', 80),
#  ('depailler', 'Tyrrell', 80),
#  ('hulkenberg', 'Force India', 79),
#  ('alesi', 'Ferrari', 79),
#  ('bottas', 'Williams', 78),
#  ('emerson_fittipaldi', 'Fittipaldi', 77),
#  ('grosjean', 'Lotus F1', 76),
#  ('watson', 'McLaren', 75),
#  ('mario_andretti', 'Team Lotus', 75),
#  ('ricciardo', 'Red Bull', 74),
#  ('perez', 'Force India', 74),
#  ('regazzoni', 'Ferrari', 73),
#  ('ghinzani', 'Osella', 73),
#  ('massa', 'Williams', 73),
#  ('coulthard', 'Red Bull', 72),
#  ('heidfeld', 'BMW Sauber', 70),
#  ('rosberg', 'Williams', 70),
#  ('alonso', 'McLaren', 69),
#  ('montoya', 'Williams', 68),
#  ('michael_schumacher', 'Benetton', 68),
#  ('gilles_villeneuve', 'Ferrari', 67),
#  ('fisichella', 'Benetton', 66),
#  ('frentzen', 'Sauber', 66),
#  ('barrichello', 'Jordan', 65),
#  ('irvine', 'Ferrari', 65),
#  ('damon_hill', 'Williams', 65),
#  ('hill', 'BRM', 64),
#  ('katayama', 'Tyrrell', 64),
#  ('arnoux', 'Ligier', 63),
#  ('mclaren', 'Cooper-Climax', 62),
#  ('alliot', 'Larrousse', 62),
#  ('keke_rosberg', 'Williams', 62),
#  ('mansell', 'Team Lotus', 62),
#  ('patrese', 'Brabham', 61),
#  ('arnoux', 'Renault', 60),
#  ('jones', 'Williams', 60),
#  ('peterson', 'Team Lotus', 59),
#  ('lauda', 'McLaren', 59),
#  ('michael_schumacher', 'Mercedes', 58),
#  ('boutsen', 'Arrows', 58),
#  ('kobayashi', 'Sauber', 58),
#  ('patrese', 'Arrows', 58),
#  ('resta', 'Force India', 58),
#  ('maldonado', 'Williams', 58),
#  ('vergne', 'Toro Rosso', 58),
#  ('lauda', 'Ferrari', 58),
#  ('kubica', 'BMW Sauber', 57),
#  ('ickx', 'Ferrari', 56),
#  ('heidfeld', 'Sauber', 55),
#  ('vettel', 'Ferrari', 55),
#  ('sainz', 'Toro Rosso', 55),
#  ('ericsson', 'Sauber', 55),
#  ('buemi', 'Toro Rosso', 55),
#  ('herbert', 'Team Lotus', 55),
#  ('fisichella', 'Renault', 54),
#  ('reutemann', 'Brabham', 54),
#  ('hulme', 'McLaren', 53),
#  ('ralf_schumacher', 'Toyota', 53),
#  ('massa', 'Sauber', 53),
#  ('barrichello', 'Honda', 53),
#  ('button', 'Honda', 53),
#  ('wurz', 'Benetton', 52),
#  ('clark', 'Lotus-Climax', 52),
#  ('button', 'BAR', 51),
#  ('salo', 'Tyrrell', 50),
#  ('kvyat', 'Toro Rosso', 50),
#  ('watson', 'Brabham', 50),
#  ('fisichella', 'Jordan', 50),
#  ('irvine', 'Jaguar', 50),
#  ('barrichello', 'Stewart', 49),
#  ('villeneuve', 'Williams', 49),
#  ('panis', 'Ligier', 49),
#  ('herbert', 'Sauber', 49),
#  ('alboreto', 'Tyrrell', 49),
#  ('mass', 'McLaren', 49),
#  ('giacomelli', 'Alfa Romeo', 49),
#  ('hunt', 'McLaren', 49),
#  ('senna', 'Team Lotus', 48),
#  ('surer', 'Arrows', 48),
#  ('satoru_nakajima', 'Team Lotus', 48),
#  ('palmer', 'Tyrrell', 48),
#  ('capelli', 'March', 48),
#  ('trulli', 'Renault', 48),
#  ('cheever', 'Arrows', 48),
#  ('berger', 'McLaren', 48),
#  ('warwick', 'Arrows', 47),
#  ('jabouille', 'Renault', 47),
#  ('nannini', 'Benetton', 46),
#  ('berger', 'Benetton', 46),
#  ('prost', 'Renault', 46),
#  ('alguersuari', 'Toro Rosso', 46),
#  ('scheckter', 'Tyrrell', 45),
#  ('manfred_winkelhock', 'ATS', 44),
#  ('tarquini', 'AGS', 44),
#  ('laffite', 'Williams', 43),
#  ('frentzen', 'Jordan', 43),
#  ('panis', 'Prost', 42),
#  ('brambilla', 'March', 42),
#  ('warwick', 'Toleman', 41),
#  ('beltoise', 'BRM', 41),
#  ('brundle', 'Tyrrell', 41),
#  ('nasr', 'Sauber', 40),
#  ('stewart', 'Tyrrell', 40),
#  ('ricciardo', 'Toro Rosso', 39),
#  ('trulli', 'Prost', 39),
#  ('sato', 'Super Aguri', 39),
#  ('glock', 'Virgin', 38),
#  ('perez', 'Sauber', 38),
#  ('gutierrez', 'Sauber', 38),
#  ('maldonado', 'Lotus F1', 38),
#  ('petrov', 'Renault', 38),
#  ('barrichello', 'Williams', 38),
#  ('cevert', 'Tyrrell', 38),
#  ('kovalainen', 'Lotus', 38),
#  ('webber', 'Williams', 37),
#  ('raikkonen', 'Lotus F1', 37),
#  ('hawthorn', 'Ferrari', 37),
#  ('trulli', 'Lotus', 37),
#  ('stuck', 'March', 36),
#  ('peterson', 'March', 36),
#  ('grosjean', 'Haas F1 Team', 36),
#  ('jolyon_palmer', 'Renault', 36),
#  ('nakajima', 'Williams', 36),
#  ('kovalainen', 'McLaren', 35),
#  ('sato', 'BAR', 35),
#  ('chilton', 'Marussia', 35),
#  ('bandini', 'Ferrari', 35),
#  ('liuzzi', 'Toro Rosso', 35),
#  ('verstappen', 'Arrows', 34),
#  ('jules_bianchi', 'Marussia', 34),
#  ('webber', 'Jaguar', 34),
#  ('reutemann', 'Ferrari', 34),
#  ('trulli', 'Jordan', 34),
#  ('panis', 'BAR', 34),
#  ('frentzen', 'Williams', 33),
#  ('glock', 'Toyota', 33),
#  ('scheckter', 'Wolf', 33),
#  ('modena', 'Brabham', 33),
#  ('cesaris', 'Alfa Romeo', 33),
#  ('morbidelli', 'Minardi', 33),
#  ('diniz', 'Sauber', 33),
#  ('ralf_schumacher', 'Jordan', 33),
#  ('streiff', 'Tyrrell', 33),
#  ('rodriguez', 'BRM', 33),
#  ('panis', 'Toyota', 33),
#  ('gene', 'Minardi', 33),
#  ('rosa', 'Arrows', 33),
#  ('emerson_fittipaldi', 'Team Lotus', 33),
#  ('alesi', 'Benetton', 33),
#  ('diniz', 'Arrows', 33),
#  ('gugelmin', 'March', 32),
#  ('patrese', 'Alfa Romeo', 32),
#  ('gugelmin', 'Leyton House', 32),
#  ('alesi', 'Sauber', 32),
#  ('cesaris', 'Tyrrell', 32),
#  ('lehto', 'Dallara', 32),
#  ('piquet', 'Williams', 32),
#  ('boutsen', 'Benetton', 32),
#  ('larini', 'Osella', 32),
#  ('max_verstappen', 'Red Bull', 32),
#  ('nilsson', 'Team Lotus', 32),
#  ('comas', 'Ligier', 32),
#  ('cheever', 'Alfa Romeo', 32),
#  ('irvine', 'Jordan', 32),
#  ('damon_hill', 'Jordan', 32),
#  ('caffi', 'Dallara', 32),
#  ('piquet', 'Benetton', 32),
#  ('boutsen', 'Ligier', 32),
#  ('brundle', 'Brabham', 32),
#  ('cesaris', 'Dallara', 32),
#  ('sala', 'Minardi', 32),
#  ('hakkinen', 'Team Lotus', 32),
#  ('boutsen', 'Williams', 32),
#  ('alboreto', 'Footwork', 32),
#  ('suzuki', 'Footwork', 32),
#  ('arnoux', 'Ferrari', 32),
#  ('fabi', 'Benetton', 32),
#  ('badoer', 'Minardi', 32),
#  ('hulme', 'McLaren-Ford', 32),
#  ('jack_brabham', 'Brabham-Repco', 32),
#  ('piquet', 'Team Lotus', 32),
#  ('satoru_nakajima', 'Tyrrell', 32),
#  ('prost', 'Ferrari', 31),
#  ('warwick', 'Renault', 31),
#  ('beltoise', 'Matra', 31),
#  ('jarier', 'Shadow', 31),
#  ('johansson', 'Ferrari', 31),
#  ('pironi', 'Tyrrell', 31),
#  ('nannini', 'Minardi', 31),
#  ('mansell', 'Ferrari', 31),
#  ('hill', 'Lotus-Ford', 31),
#  ('reutemann', 'Williams', 31),
#  ('phil_hill', 'Ferrari', 31),
#  ('brambilla', 'Surtees', 31),
#  ('comas', 'Larrousse', 31),
#  ('tambay', 'Renault', 30),
#  ('fisichella', 'Force India', 30),
#  ('tambay', 'McLaren', 30),
#  ('zonta', 'BAR', 30),
#  ('klien', 'Red Bull', 30),
#  ('merzario', 'Merzario', 30),
#  ('schneider', 'Zakspeed', 30),
#  ('capelli', 'Leyton House', 30),
#  ('rosa', 'Jaguar', 30),
#  ('surtees', 'Ferrari', 30),
#  ('pirro', 'Dallara', 30),
#  ('beaufort', 'Porsche', 29),
#  ('scheckter', 'Ferrari', 29),
#  ('bernoldi', 'Arrows', 29),
#  ('alliot', 'RAM', 29),
#  ('ginther', 'BRM', 29),
#  ('karthikeyan', 'HRT', 29),
#  ('stewart', 'BRM', 29),
#  ('alesi', 'Prost', 29),
#  ('emerson_fittipaldi', 'McLaren', 29),
#  ('ascari', 'Ferrari', 29),
#  ('hill', 'Team Lotus', 28),
#  ('mass', 'Arrows', 28),
#  ('matta', 'Toyota', 28),
#  ('keke_rosberg', 'Fittipaldi', 28),
#  ('piquet_jr', 'Renault', 28),
#  ('speed', 'Toro Rosso', 28),
#  ('serra', 'Fittipaldi', 28),
#  ('pironi', 'Ferrari', 27),
#  ('gachot', 'Pacific', 27),
#  ('montoya', 'McLaren', 27),
#  ('fittipaldi', 'Minardi', 27),
#  ('bourdais', 'Toro Rosso', 27),
#  ('pryce', 'Shadow', 27),
#  ('amon', 'Ferrari', 27),
#  ('fabi', 'Toleman', 27),
#  ('hunt', 'Hesketh', 27),
#  ('mclaren', 'McLaren-Ford', 27),
#  ('hailwood', 'Surtees', 27),
#  ('rebaque', 'Team Lotus', 27),
#  ('cesaris', 'Ligier', 27),
#  ('jarier', 'Tyrrell', 27),
#  ('brundle', 'Ligier', 27),
#  ('morbidelli', 'Footwork', 26),
#  ('marques', 'Minardi', 26),
#  ('wendlinger', 'Sauber', 26),
#  ('trips', 'Ferrari', 26),
#  ('schell', 'Maserati', 26),
#  ('dalmas', 'Larrousse', 25),
#  ('jack_brabham', 'Brabham', 25),
#  ('vettel', 'Toro Rosso', 25),
#  ('herbert', 'Benetton', 25),
#  ('coulthard', 'Williams', 25),
#  ('dalmas', 'AGS', 25),
#  ('behra', 'Maserati', 25),
#  ('wilson_fittipaldi', 'Brabham', 25),
#  ('magnussen', 'Stewart', 24),
#  ('beuttler', 'March', 24),
#  ('ickx', 'Team Lotus', 24),
#  ('liuzzi', 'Force India', 24),
#  ('pace', 'Brabham', 24),
#  ('anderson', 'Brabham-Climax', 24),
#  ('palmer', 'Zakspeed', 24),
#  ('jack_brabham', 'Cooper-Climax', 24),
#  ('alesi', 'Tyrrell', 24),
#  ('lamy', 'Minardi', 24),
#  ('farina', 'Ferrari', 23),
#  ('revson', 'McLaren', 23),
#  ('jarier', 'Osella', 23),
#  ('hill', 'Brabham', 23),
#  ('tambay', 'Ferrari', 23),
#  ('oliver', 'BRM', 23),
#  ('kvyat', 'Red Bull', 23),
#  ('collins', 'Ferrari', 23),
#  ('alliot', 'Ligier', 23),
#  ('max_verstappen', 'Toro Rosso', 23),
#  ('ertl', 'Hesketh', 23),
#  ('lunger', 'McLaren', 23),
#  ('zanardi', 'Team Lotus', 22),
#  ('amon', 'Matra', 22),
#  ('siffert', 'Lotus-Ford', 22),
#  ('bellof', 'Tyrrell', 22),
#  ('villoresi', 'Ferrari', 22),
#  ('pace', 'Surtees', 22),
#  ('rebaque', 'Brabham', 22),
#  ('surtees', 'Honda', 21),
#  ('davidson', 'Super Aguri', 21),
#  ('kevin_magnussen', 'Renault', 21),
#  ('larrauri', 'Euro Brun', 21),
#  ('ganley', 'BRM', 21),
#  ('fangio', 'Maserati', 21),
#  ('wehrlein', 'Manor Marussia', 21),
#  ('stewart', 'Matra-Ford', 21),
#  ('campos', 'Minardi', 21),
#  ('gutierrez', 'Haas F1 Team', 21),
#  ('petrov', 'Caterham', 20),
#  ('kevin_magnussen', 'McLaren', 20),
#  ('bernard', 'Larrousse', 20),
#  ('suzuki', 'Larrousse', 20),
#  ('pic', 'Marussia', 20),
#  ('glock', 'Marussia', 20),
#  ('behra', 'Gordini', 20),
#  ('rosa', 'HRT', 20),
#  ('bruno_senna', 'Williams', 20),
#  ('kovalainen', 'Caterham', 20),
#  ('graffenried', 'Maserati', 20),
#  ('regazzoni', 'Ensign', 20),
#  ('jones', 'Lola', 20),
#  ('karthikeyan', 'Jordan', 19),
#  ('trintignant', 'Ferrari', 19),
#  ('albers', 'Minardi', 19),
#  ('hulkenberg', 'Williams', 19),
#  ('kubica', 'Renault', 19),
#  ('perez', 'McLaren', 19),
#  ('villeneuve', 'Sauber', 19),
#  ('hulkenberg', 'Sauber', 19),
#  ('grassi', 'Virgin', 19),
#  ('rindt', 'Cooper-Maserati', 19),
#  ('garde', 'Caterham', 19),
#  ('maggs', 'Cooper-Climax', 19),
#  ('gurney', 'Brabham-Climax', 19),
#  ('monteiro', 'Jordan', 19),
#  ('sutil', 'Sauber', 19),
#  ('ambrosio', 'Virgin', 19),
#  ('pic', 'Caterham', 19),
#  ('surtees', 'Surtees', 19),
#  ('siffert', 'Brabham-BRM', 19),
#  ('trevor_taylor', 'Lotus-Climax', 19),
#  ('cesaris', 'Jordan', 18),
#  ('bruno_senna', 'HRT', 18),
#  ('jarier', 'Ligier', 18),
#  ('liuzzi', 'HRT', 18),
#  ('fisichella', 'Sauber', 18),
#  ('heidfeld', 'Jordan', 18),
#  ('lehto', 'Sauber', 18),
#  ('stevens', 'Manor Marussia', 18),
#  ('danner', 'Zakspeed', 18),
#  ('klien', 'Jaguar', 18),
#  ('brooks', 'Vanwall', 18),
#  ('hill', 'Lola', 18),
#  ('hulme', 'Brabham-Repco', 18),
#  ('baumgartner', 'Minardi', 18),
#  ('johansson', 'Onyx', 18),
#  ('bruni', 'Minardi', 18),
#  ('siffert', 'Cooper-Maserati', 18),
#  ('barrichello', 'Brawn', 17),
#  ('diniz', 'Forti', 17),
#  ('verstappen', 'Tyrrell', 17),
#  ('watson', 'Penske', 17),
#  ('button', 'Brawn', 17),
#  ('mcnish', 'Toyota', 17),
#  ('kovalainen', 'Renault', 17),
#  ('nakano', 'Prost', 17),
#  ('sutil', 'Spyker', 17),
#  ('salo', 'Sauber', 17),
#  ('moreno', 'Forti', 17),
#  ('herbert', 'Jaguar', 17),
#  ('button', 'Benetton', 17),
#  ('daly', 'Tyrrell', 17),
#  ('button', 'Williams', 17),
#  ('webber', 'Minardi', 17),
#  ('gachot', 'Larrousse', 17),
#  ('inoue', 'Footwork', 17),
#  ('montermini', 'Pacific', 17),
#  ('bonnier', 'BRM', 17),
#  ('sato', 'Jordan', 17),
#  ('jack_brabham', 'Brabham-Climax', 17),
#  ('katayama', 'Minardi', 17),
#  ('gould', 'Maserati', 17),
#  ('mazzacane', 'Minardi', 17),
#  ('bonnier', 'Brabham-Climax', 17),
#  ('damon_hill', 'Arrows', 17),
#  ('peterson', 'Tyrrell', 17),
#  ('caffi', 'Osella', 17),
#  ('ribeiro', 'March', 17),
#  ('button', 'Renault', 17),
#  ('gonzalez', 'Ferrari', 17),
#  ('alonso', 'Minardi', 17),
#  ('raikkonen', 'Sauber', 17),
#  ('salo', 'Toyota', 17),
#  ('herbert', 'Stewart', 16),
#  ('vandoorne', 'McLaren', 16),
#  ('verstappen', 'Footwork', 16),
#  ('brundle', 'Jordan', 16),
#  ('takagi', 'Arrows', 16),
#  ('warwick', 'Team Lotus', 16),
#  ('schell', 'BRM', 16),
#  ('zanardi', 'Williams', 16),
#  ('martini', 'Dallara', 16),
#  ('cesaris', 'Rial', 16),
#  ('johansson', 'Ligier', 16),
#  ('suzuki', 'Zakspeed', 16),
#  ('diniz', 'Ligier', 16),
#  ('katayama', 'Larrousse', 16),
#  ('kobayashi', 'Caterham', 16),
#  ('ghinzani', 'Zakspeed', 16),
#  ('belmondo', 'Pacific', 16),
#  ('grouillard', 'Tyrrell', 16),
#  ('blundell', 'Ligier', 16),
#  ('brabham', 'Simtek', 16),
#  ('spence', 'Lotus-Climax', 16),
#  ('regazzoni', 'Shadow', 16),
#  ('bonnier', 'Porsche', 16),
#  ('streiff', 'AGS', 16),
#  ('grouillard', 'Ligier', 16),
#  ('dumfries', 'Team Lotus', 16),
#  ('moss', 'Maserati', 16),
#  ('keke_rosberg', 'McLaren', 16),
#  ('gurney', 'Eagle-Weslake', 16),
#  ('brundle', 'McLaren', 16),
#  ('prost', 'Williams', 16),
#  ('modena', 'Jordan', 16),
#  ('mario_andretti', 'Parnelli', 16),
#  ('salo', 'Arrows', 16),
#  ('stommelen', 'Brabham', 16),
#  ('jack_brabham', 'Cooper', 16),
#  ('larini', 'Ligier', 16),
#  ('bonnier', 'Cooper-Maserati', 16),
#  ('johansson', 'McLaren', 16),
#  ('patrese', 'Benetton', 16),
#  ('berger', 'Arrows', 16),
#  ('tarquini', 'Fondmetal', 16),
#  ('alboreto', 'Arrows', 16),
#  ('wurz', 'Williams', 16),
#  ('cesaris', 'Minardi', 16),
#  ('verstappen', 'Minardi', 16),
#  ('nakano', 'Minardi', 16),
#  ('takagi', 'Tyrrell', 16),
#  ('ericsson', 'Caterham', 16),
#  ('modena', 'Euro Brun', 16),
#  ('salazar', 'ATS', 16),
#  ('warwick', 'Footwork', 16),
#  ('pace', 'Brabham-Alfa Romeo', 16),
#  ('modena', 'Tyrrell', 16),
#  ('gachot', 'Coloni', 16),
#  ('bailey', 'Tyrrell', 16),
#  ('brundle', 'Benetton', 16),
#  ('grouillard', 'Osella', 16),
#  ('blundell', 'Brabham', 16),
#  ('stuck', 'Shadow', 16),
#  ('poele', 'Lambo', 16),
#  ('blundell', 'Tyrrell', 16),
#  ('manzon', 'Gordini', 16),
#  ('fittipaldi', 'Footwork', 16),
#  ('rosset', 'Footwork', 16),
#  ('gugelmin', 'Jordan', 16),
#  ('tuero', 'Minardi', 16),
#  ('moreno', 'Coloni', 16),
#  ('lauda', 'Brabham', 16),
#  ('larini', 'Lambo', 16),
#  ('alboreto', 'Minardi', 16),
#  ('heidfeld', 'Prost', 16),
#  ('cesaris', 'Brabham', 16),
#  ('brundle', 'Zakspeed', 16),
#  ('yoong', 'Minardi', 16),
#  ('tarquini', 'Coloni', 16),
#  ('baldi', 'Alfa Romeo', 15),
#  ('ireland', 'Lotus-Climax', 15),
#  ('moss', 'Vanwall', 15),
#  ('musso', 'Ferrari', 15),
#  ('gethin', 'BRM', 15),
#  ('boesel', 'Ligier', 15),
#  ('fangio', 'Alfa Romeo', 15),
#  ('pescarolo', 'Matra', 15),
#  ('stroll', 'Williams', 15),
#  ('cheever', 'Tyrrell', 15),
#  ('rosier', 'Ferrari', 15),
#  ('cheever', 'Renault', 15),
#  ('rosa', 'Sauber', 15),
#  ('reutemann', 'Team Lotus', 15),
#  ('senna', 'Toleman', 15),
#  ('palmer', 'RAM', 15),
#  ('bottas', 'Mercedes', 15),
#  ('barilla', 'Minardi', 15),
#  ('cheever', 'Ligier', 15),
#  ('angelis', 'Shadow', 15),
#  ('baldi', 'Arrows', 15),
#  ('stuck', 'ATS', 15),
#  ('guerrero', 'Ensign', 15),
#  ('kevin_magnussen', 'Haas F1 Team', 15),
#  ('giacomelli', 'Toleman', 15),
#  ('sullivan', 'Tyrrell', 15),
#  ('mario_andretti', 'Alfa Romeo', 15),
#  ('cesaris', 'McLaren', 15),
#  ('hulkenberg', 'Renault', 15),
#  ('gabbiani', 'Osella', 15),
#  ('ghinzani', 'Ligier', 15),
#  ('lammers', 'Shadow', 15),
#  ('ocon', 'Force India', 15),
#  ('corrado_fabi', 'Osella', 15),
#  ('hesnault', 'Ligier', 15),
#  ('daly', 'March', 15),
#  ('boesel', 'March', 15),
#  ('blundell', 'McLaren', 15),
#  ('regazzoni', 'Williams', 15),
#  ('gurney', 'Porsche', 15),
#  ('tambay', 'Lola', 15),
#  ('alboreto', 'Lola', 14),
#  ('albers', 'MF1', 14),
#  ('capelli', 'Ferrari', 14),
#  ('mieres', 'Maserati', 14),
#  ('jones', 'Surtees', 14),
#  ('moreno', 'Euro Brun', 14),
#  ('lehto', 'Onyx', 14),
#  ('ian_scheckter', 'March', 14),
#  ('daly', 'Ensign', 14),
#  ('cheever', 'Osella', 14),
#  ('stommelen', 'Arrows', 14),
#  ('rosier', 'Talbot-Lago', 14),
#  ('merzario', 'Iso Marlboro', 14),
#  ('heidfeld', 'Williams', 14),
#  ('pryce', 'Shadow-Ford', 14),
#  ('farina', 'Alfa Romeo', 14),
#  ('stuck', 'Brabham', 14),
#  ('castellotti', 'Ferrari', 14),
#  ('godia', 'Maserati', 14),
#  ('guerrero', 'Theodore', 14),
#  ('ganley', 'Iso Marlboro', 14),
#  ('oliver', 'Shadow', 14),
#  ('monteiro', 'MF1', 14),
#  ('wendlinger', 'March', 14),
#  ('taruffi', 'Ferrari', 14),
#  ('ireland', 'Team Lotus', 14),
#  ('merzario', 'March', 14),
#  ('regazzoni', 'BRM', 14),
#  ('firman', 'Jordan', 14),
#  ('lauda', 'BRM', 14),
#  ('donnelly', 'Team Lotus', 14),
#  ('pantano', 'Jordan', 14),
#  ('langes', 'Euro Brun', 14),
#  ('pironi', 'Ligier', 14),
#  ('brabham', 'Brabham', 14),
#  ('mass', 'Surtees', 14),
#  ('jones', 'Shadow', 14),
#  ('caffi', 'Arrows', 14),
#  ('badoer', 'Lola', 14),
#  ('danner', 'Rial', 13),
#  ('macklin', 'HWM', 13),
#  ('lauda', 'Brabham-Alfa Romeo', 13),
#  ('bernard', 'Lola', 13),
#  ('mario_andretti', 'Ferrari', 13),
#  ('mass', 'ATS', 13),
#  ('rosset', 'Tyrrell', 13),
#  ('amon', 'March', 13),
#  ('moreno', 'Benetton', 13),
#  ('grouillard', 'Fondmetal', 13),
#  ('chaves', 'Coloni', 13),
#  ('henton', 'Tyrrell', 13),
#  ('wehrlein', 'Sauber', 13),
#  ('lewis-evans', 'Vanwall', 13),
#  ('bernard', 'Ligier', 13),
#  ('keegan', 'Surtees', 13),
#  ('andretti', 'McLaren', 13),
#  ('stohr', 'Arrows', 13),
#  ('eaton', 'BRM', 13),
#  ('siffert', 'Lotus-BRM', 13),
#  ('suzuki', 'Lola', 13),
#  ('courage', 'BRM', 13),
#  ('merhi', 'Manor Marussia', 13),
#  ('cecotto', 'Theodore', 13),
#  ('claes', 'Talbot-Lago', 13),
#  ('adamich', 'Surtees', 13),
#  ('piquet', 'Brabham-Alfa Romeo', 13),
#  ('siffert', 'March', 13),
#  ('rothengatter', 'Zakspeed', 13),
#  ('wilson_fittipaldi', 'Fittipaldi', 13),
#  ('spence', 'BRM', 12),
#  ('kling', 'Mercedes', 12),
#  ('reutemann', 'Brabham-Alfa Romeo', 12),
#  ('gachot', 'Onyx', 12),
#  ('henton', 'Toleman', 12),
#  ('ireland', 'Lotus-BRM', 12),
#  ('pescarolo', 'BRM', 12),
#  ('jarier', 'Shadow-Ford', 12),
#  ('bonetto', 'Maserati', 12),
#  ('schenken', 'Surtees', 12),
#  ('rindt', 'Brabham-Repco', 12),
#  ('borgudd', 'ATS', 12),
#  ('caffi', 'Footwork', 12),
#  ('keke_rosberg', 'Wolf', 12),
#  ('ireland', 'BRP', 12),
#  ('bonnier', 'Maserati', 12),
#  ('salvadori', 'Cooper', 12),
#  ('lauda', 'March', 12),
#  ('lombardi', 'March', 12),
#  ('bira', 'Maserati', 12),
#  ('barbazza', 'AGS', 12),
#  ('lunger', 'Surtees', 12),
#  ('beltoise', 'Matra-Ford', 12),
#  ('haryanto', 'Manor Marussia', 12),
#  ('keegan', 'Hesketh', 12),
#  ('giacomelli', 'Life', 12),
#  ('fabre', 'AGS', 12),
#  ('villeneuve', 'BMW Sauber', 12),
#  ('trintignant', 'Gordini', 12),
#  ('daly', 'Williams', 12),
#  ('frentzen', 'Arrows', 12),
#  ('follmer', 'Shadow', 12),
#  ('surer', 'Brabham', 12),
#  ('hill', 'Shadow', 12),
#  ('marimon', 'Maserati', 12),
#  ('gregory', 'Cooper-Climax', 12),
#  ('fangio', 'Mercedes', 12),
#  ('friesacher', 'Minardi', 11),
#  ('merzario', 'Ferrari', 11),
#  ('belmondo', 'March', 11),
#  ('foitek', 'Euro Brun', 11),
#  ('neve', 'March', 11),
#  ('bonnier', 'Cooper-Climax', 11),
#  ('surer', 'ATS', 11),
#  ('ginther', 'Honda', 11),
#  ('musso', 'Maserati', 11),
#  ('etancelin', 'Talbot-Lago', 11),
#  ('warwick', 'Brabham', 11),
#  ('bucknum', 'Honda', 11),
#  ('hailwood', 'McLaren', 11),
#  ('watson', 'Surtees', 11),
#  ('pace', 'March', 11),
#  ('migault', 'BRM', 11),
#  ('boullion', 'Sauber', 11),
#  ('donohue', 'Penske', 11),
#  ('amon', 'Lotus-BRM', 11),
#  ('fabi', 'Brabham', 11),
#  ('pizzonia', 'Jaguar', 11),
#  ('baldi', 'Spirit', 11),
#  ('heidfeld', 'Renault', 11),
#  ('siffert', 'BRM', 11),
#  ('wilson', 'Minardi', 11),
#  ('ickx', 'Brabham-Ford', 11),
#  ('ricciardo', 'HRT', 11),
#  ('jarier', 'Penske', 11),
#  ('cabantous', 'Talbot-Lago', 10),
#  ('rindt', 'Lotus-Ford', 10),
#  ('montermini', 'Forti', 10),
#  ('clark', 'Lotus-Ford', 10),
#  ('surtees', 'BRM', 10),
#  ('rosier', 'Maserati', 10),
#  ('stommelen', 'Surtees', 10),
#  ('pescarolo', 'March-Ford', 10),
#  ('oliver', 'Lotus-Ford', 10),
#  ('burti', 'Prost', 10),
#  ('verstappen', 'Benetton', 10),
#  ('chiesa', 'Fondmetal', 10),
#  ('miles', 'Team Lotus', 10),
#  ('courage', 'Brabham-Ford', 10),
#  ('adamich', 'McLaren-Alfa Romeo', 10),
#  ('rindt', 'Team Lotus', 10),
#  ('gachot', 'Jordan', 10),
#  ('schenken', 'Brabham', 10),
#  ('poele', 'Brabham', 10),
#  ('amon', 'Ensign', 10),
#  ('cecotto', 'Toleman', 10),
#  ('lammers', 'ATS', 10),
#  ('beretta', 'Larrousse', 10),
#  ('gonzalez', 'Maserati', 10),
#  ('ginther', 'Ferrari', 10),
#  ('raphanel', 'Coloni', 10),
#  ('pescarolo', 'March', 10),
#  ('flockhart', 'BRM', 10),
#  ('weidler', 'Rial', 10),
#  ('badoer', 'Forti', 10),
#  ('mass', 'March', 10),
#  ('pirro', 'Benetton', 10),
#  ('boutsen', 'Jordan', 10),
#  ('peterson', 'March-Ford', 10),
#  ('brooks', 'BRM', 10),
#  ('mairesse', 'Ferrari', 10),
#  ('danner', 'Arrows', 10),
#  ('phil_hill', 'Cooper-Climax', 10),
#  ('menditeguy', 'Maserati', 10),
#  ('hailwood', 'Lotus-BRM', 10),
#  ('stewart', 'March', 10),
#  ('parsons', 'Kurtis Kraft', 10),
#  ('gurney', 'Brabham', 10),
#  ('chandhok', 'HRT', 10),
#  ('fangio', 'Ferrari', 10),
#  ('jarier', 'March', 10),
#  ('walker', 'Team Lotus', 10),
#  ('rindt', 'Cooper-Climax', 10),
#  ('hunt', 'March', 10),
#  ('scarfiotti', 'Ferrari', 9),
#  ('pescarolo', 'Surtees', 9),
#  ('trintignant', 'Cooper-Maserati', 9),
#  ('manfred_winkelhock', 'RAM', 9),
#  ('baghetti', 'ATS', 9),
#  ('rosa', 'McLaren', 9),
#  ('binder', 'Surtees', 9),
#  ('ickx', 'Ensign', 9),
#  ('surtees', 'Lola', 9),
#  ('salvadori', 'Lola', 9),
#  ('berg', 'Osella', 9),
#  ('edwards', 'Lola', 9),
#  ('brise', 'Embassy Hill', 9),
#  ('marko', 'BRM', 9),
#  ('trintignant', 'Cooper-Climax', 9),
#  ('evans', 'BRM', 9),
#  ('pizzonia', 'Williams', 9),
#  ('alan_brown', 'Cooper', 9),
#  ('behra', 'BRM', 9),
#  ('acheson', 'RAM', 9),
#  ('verstappen', 'Stewart', 9),
#  ('whitehead', 'Ferrari', 9),
#  ('surer', 'Ensign', 9),
#  ('scarlatti', 'Maserati', 9),
#  ('cesaris', 'Sauber', 9),
#  ('ocon', 'Manor Marussia', 9),
#  ('patrese', 'Shadow', 9),
#  ('wisell', 'Lotus-Ford', 9),
#  ('mantovani', 'Maserati', 9),
#  ('emerson_fittipaldi', 'Lotus-Ford', 9),
#  ('hall', 'Lotus-BRM', 9),
#  ('collins', 'HWM', 9),
#  ('trintignant', 'Lotus-Climax', 9),
#  ('schell', 'Vanwall', 9),
#  ('cevert', 'March', 9),
#  ('villoresi', 'Maserati', 9),
#  ('albers', 'Spyker', 9),
#  ('gregory', 'Lotus-BRM', 9),
#  ('salazar', 'Ensign', 9),
#  ('lamy', 'Team Lotus', 8),
#  ('rodriguez', 'Ferrari', 8),
#  ('alboreto', 'Larrousse', 8),
#  ('perdisa', 'Maserati', 8),
#  ('irwin', 'BRM', 8),
#  ('rothengatter', 'Spirit', 8),
#  ('gregory', 'Maserati', 8),
#  ('ligier', 'Cooper-Maserati', 8),
#  ('tambay', 'Ensign', 8),
#  ('attwood', 'Lotus-BRM', 8),
#  ('gurney', 'Eagle-Climax', 8),
#  ('spence', 'Lotus-BRM', 8),
#  ('villota', 'McLaren', 8),
#  ('fisichella', 'Minardi', 8),
#  ('allison', 'Team Lotus', 8),
#  ('hulme', 'Brabham-Climax', 8),
#  ('morbidelli', 'Sauber', 8),
#  ('gartner', 'Osella', 8),
#  ('doornbos', 'Minardi', 8),
#  ('schenken', 'Trojan', 8),
#  ('foitek', 'Onyx', 8),
#  ('surer', 'Theodore', 8),
#  ('surtees', 'Cooper-Climax', 8),
#  ('tambay', 'Ligier', 8),
#  ('moss', 'Lotus-Climax', 8),
#  ('rodriguez', 'Cooper-Maserati', 8),
#  ('ickx', 'Ligier', 8),
#  ('lewis', 'Cooper-Climax', 8),
#  ('bruno_senna', 'Renault', 8),
#  ('chiron', 'Maserati', 8),
#  ('barbazza', 'Minardi', 8),
#  ('lammers', 'Ensign', 8),
#  ('moss', 'Cooper-Climax', 8),
#  ('paletti', 'Osella', 8),
#  ('phil_hill', 'ATS', 8),
#  ('hanks', 'Kurtis Kraft', 8),
#  ('fagioli', 'Alfa Romeo', 8),
#  ('gendebien', 'Ferrari', 8),
#  ('damon_hill', 'Brabham', 8),
#  ('depailler', 'Alfa Romeo', 8),
#  ('ickx', 'Wolf', 8),
#  ('moreno', 'Andrea Moda', 8),
#  ('arnoux', 'Martini', 8),
#  ('agabashian', 'Kurtis Kraft', 8),
#  ('jack_brabham', 'Brabham-Ford', 8),
#  ('baghetti', 'Ferrari', 8),
#  ('paul_russo', 'Kurtis Kraft', 8),
#  ('burgess', 'Cooper-Maserati', 8),
#  ('stommelen', 'March', 8),
#  ('gardner', 'Brabham-BRM', 7),
#  ('ramos', 'Gordini', 7),
#  ('joachim_winkelhock', 'AGS', 7),
#  ('bianchi', 'Cooper-BRM', 7),
#  ('schiattarella', 'Simtek', 7),
#  ('trintignant', 'Simca', 7),
#  ('gurney', 'BRM', 7),
#  ('opel', 'Ensign', 7),
#  ('trintignant', 'BRM', 7),
#  ('brooks', 'Ferrari', 7),
#  ('elford', 'Cooper-BRM', 7),
#  ('grosjean', 'Renault', 7),
#  ('linden', 'Kurtis Kraft', 7),
#  ('settember', 'Scirocco', 7),
#  ('arundell', 'Lotus-Climax', 7),
#  ('schell', 'Gordini', 7),
#  ('bell', 'Surtees', 7),
#  ('keegan', 'Williams', 7),
#  ('zunino', 'Brabham', 7),
#  ('papis', 'Footwork', 7),
#  ('mccarthy', 'Andrea Moda', 7),
#  ('baghetti', 'BRM', 7),
#  ('rothengatter', 'Osella', 7),
#  ('burgess', 'Scirocco', 7),
#  ('gethin', 'McLaren-Ford', 7),
#  ('manzon', 'Simca', 7),
#  ('trulli', 'Minardi', 7),
#  ('depailler', 'Ligier', 7),
#  ('yamamoto', 'HRT', 7),
#  ('fischer', 'Ferrari', 7),
#  ('gavin', 'Matra-Ford', 7),
#  ('gounon', 'Simtek', 7),
#  ('trevor_taylor', 'BRP', 7),
#  ('yamamoto', 'Super Aguri', 7),
#  ('gerini', 'Maserati', 7),
#  ('mcalpine', 'Connaught', 7),
#  ('kennedy', 'Shadow', 7),
#  ('attwood', 'BRM', 7),
#  ('amon', 'Lola', 7),
#  ('hunt', 'Wolf', 7),
#  ('stacey', 'Team Lotus', 7),
#  ('arundell', 'Lotus-BRM', 7),
#  ('piotti', 'Maserati', 7),
#  ('bonnier', 'McLaren-BRM', 7),
#  ('merzario', 'Wolf', 7),
#  ('leclere', 'Wolf', 7),
#  ('allison', 'Ferrari', 7),
#  ('salvadori', 'Cooper-Climax', 7),
#  ('surtees', 'Cooper-Maserati', 7),
#  ('trintignant', 'Cooper', 7),
#  ('moss', 'Mercedes', 7),
#  ('tambay', 'Theodore', 7),
#  ('gethin', 'McLaren', 7),
#  ('ghinzani', 'Toleman', 7),
#  ('stommelen', 'Lola', 7),
#  ('schuppan', 'Ensign', 7),
#  ('montagny', 'Super Aguri', 7),
#  ('yamamoto', 'Spyker', 7),
#  ('moser', 'Brabham-Ford', 7),
#  ('herrmann', 'Mercedes', 7),
#  ('parkes', 'Ferrari', 6),
#  ('adamich', 'March-Alfa Romeo', 6),
#  ('hayje', 'March', 6),
#  ('raphanel', 'Rial', 6),
#  ('edwards', 'Hesketh', 6),
#  ('scheckter', 'McLaren', 6),
#  ('jarier', 'ATS', 6),
#  ('kinnunen', 'Surtees', 6),
#  ('halford', 'Maserati', 6),
#  ('wharton', 'Cooper', 6),
#  ('perkins', 'Boro', 6),
#  ('opel', 'Brabham', 6),
#  ('daywalt', 'Kurtis Kraft', 6),
#  ('salvadori', 'Maserati', 6),
#  ('giacomelli', 'McLaren', 6),
#  ('manzon', 'Ferrari', 6),
#  ('andre_pilette', 'Gordini', 6),
#  ('mclaren', 'McLaren-BRM', 6),
#  ('mcgrath', 'Kurtis Kraft', 6),
#  ('portago', 'Ferrari', 6),
#  ('bettenhausen', 'Kurtis Kraft', 6),
#  ('johansson', 'Spirit', 6),
#  ('gurney', 'McLaren-Ford', 6),
#  ('lehto', 'Benetton', 6),
#  ('brooks', 'Cooper-Climax', 6),
#  ('rathmann', 'Kurtis Kraft', 6),
#  ('moser', 'Bellasi', 6),
#  ('chiron', 'Talbot-Lago', 6),
#  ('levegh', 'Talbot-Lago', 6),
#  ('maglioli', 'Ferrari', 6),
#  ('charlton', 'Team Lotus', 6),
#  ('lammers', 'Theodore', 6),
#  ('danner', 'Osella', 6),
#  ('suzuki', 'Ligier', 6),
#  ('lavaggi', 'Minardi', 6),
#  ('salazar', 'RAM', 6),
#  ('wisell', 'BRM', 6),
#  ('ricardo_rodriguez', 'Ferrari', 6),
#  ('jack_brabham', 'Lotus-Climax', 6),
#  ('wunderink', 'Ensign', 6),
#  ('salo', 'Ferrari', 6),
#  ('hoffmann', 'Fittipaldi', 6),
#  ('clark', 'Team Lotus', 6),
#  ('merzario', 'Williams', 6),
#  ('zonta', 'Toyota', 6),
#  ('naylor', 'JBW', 6),
#  ('bertaggia', 'Coloni', 6),
#  ('salvadori', 'Aston Martin', 6),
#  ('rebaque', 'Hesketh', 6),
#  ('wilson', 'Jaguar', 5),
#  ('gregory', 'Cooper-Maserati', 5),
#  ('verstappen', 'Simtek', 5),
#  ('landi', 'Maserati', 5),
#  ('fisichella', 'Ferrari', 5),
#  ('courage', 'De Tomaso', 5),
#  ('brambilla', 'Alfa Romeo', 5),
#  ('bonnier', 'McLaren', 5),
#  ('kiesa', 'Minardi', 5),
#  ('ashley', 'Hesketh', 5),
#  ('burti', 'Jaguar', 5),
#  ('fairman', 'Connaught', 5),
#  ('wharton', 'Maserati', 5),
#  ('larini', 'Sauber', 5),
#  ('kessel', 'Brabham-Ford', 5),
#  ('swaters', 'Ferrari', 5),
#  ('purley', 'March', 5),
#  ('gendebien', 'Cooper-Climax', 5),
#  ('love', 'Cooper-Climax', 5),
#  ('galli', 'Iso Marlboro', 5),
#  ('herrmann', 'Porsche', 5),
#  ('sanesi', 'Alfa Romeo', 5),
#  ('salvadori', 'Connaught', 5),
#  ('barth', 'Porsche', 5),
#  ('keke_rosberg', 'ATS', 5),
#  ('daigh', 'Scarab', 5),
#  ('roig', 'March-Ford', 5),
#  ('ligier', 'Brabham-Repco', 5),
#  ('hawthorn', 'Cooper', 5),
#  ('lennep', 'Iso Marlboro', 5),
#  ('seidel', 'Lotus-Climax', 5),
#  ('pollet', 'Gordini', 5),
#  ('johansson', 'Tyrrell', 5),
#  ('jabouille', 'Ligier', 5),
#  ('connor', 'Kurtis Kraft', 5),
#  ('naspetti', 'March', 5),
#  ('maggs', 'BRM', 5),
#  ('keke_rosberg', 'Theodore', 5),
#  ('lovely', 'Team Lotus', 5),
#  ('herrmann', 'Maserati', 5),
#  ('zorzi', 'Shadow', 5),
#  ('rossi', 'Manor Marussia', 5),
#  ('gaillard', 'Ensign', 5),
#  ('villota', 'March', 5),
#  ('christie', 'Kurtis Kraft', 5),
#  ('lees', 'Shadow', 5),
#  ('lovely', 'Lotus-Ford', 5),
#  ('mario_andretti', 'March', 5),
#  ('alesi', 'Jordan', 5),
#  ('henry_taylor', 'Lotus-Climax', 5),
#  ('frentzen', 'Prost', 5),
#  ('miles', 'Lotus-Ford', 5),
#  ('henry_taylor', 'Cooper-Climax', 5),
#  ('moss', 'Team Lotus', 5),
#  ('keegan', 'March', 5),
#  ('brandon', 'Cooper', 5),
#  ('shelby', 'Maserati', 5),
#  ('salazar', 'March', 5),
#  ('laffite', 'Iso Marlboro', 5),
#  ('bondurant', 'BRM', 5),
#  ('byrne', 'Theodore', 5),
#  ('purley', 'LEC', 5),
#  ('bandini', 'BRM', 5),
#  ('beuttler', 'March-Ford', 5),
#  ('burgess', 'Cooper-Climax', 5),
#  ('adamich', 'Brabham', 5),
#  ('simon', 'Simca', 4),
#  ('serra', 'Arrows', 4),
#  ('albers', 'Spyker MF1', 4),
#  ('giunti', 'Ferrari', 4),
#  ('leoni', 'Ensign', 4),
#  ('henton', 'March', 4),
#  ('glock', 'Jordan', 4),
#  ('trimmer', 'Maki', 4),
#  ('marsh', 'BRM', 4),
#  ('bandini', 'Cooper-Maserati', 4),
#  ('johansson', 'Footwork', 4),
#  ('clark', 'Lotus-BRM', 4),
#  ('ashmore', 'Lotus-Climax', 4),
#  ('bianco', 'Maserati', 4),
#  ('liuzzi', 'Red Bull', 4),
#  ('gurney', 'Ferrari', 4),
#  ('redman', 'Shadow', 4),
#  ('greene', 'Gilby', 4),
#  ('estefano', 'De Tomaso', 4),
#  ('ide', 'Super Aguri', 4),
#  ('bayol', 'Gordini', 4),
#  ('dick_rathmann', 'Watson', 4),
#  ('gerard', 'Cooper', 4),
#  ('amon', 'Tecno', 4),
#  ('gregory', 'Lotus-Climax', 4),
#  ('berger', 'ATS', 4),
#  ('streiff', 'Ligier', 4),
#  ('bonetto', 'Alfa Romeo', 4),
#  ('taylor', 'Brabham-BRM', 4),
#  ('moser', 'Brabham-Repco', 4),
#  ('teague', 'Kurtis Kraft', 4),
#  ('hoyt', 'Kurtis Kraft', 4),
#  ('bucci', 'Gordini', 4),
#  ('bianchi', 'Cooper-Climax', 4),
#  ...]

# %% [markdown]
# ## 3) Now we have found the most driven vehicles even for those who didn't finish the race. Extend the query from 2 by removing all tuples from the result where the status is not "Finished".

# %%
# %%sql SELECT drivers.driverref, constructors.name, count(*) FROM drivers
# JOIN results on results.driverid = drivers.driverid
# JOIN constructors USING (constructorid)
# JOIN status USING (statusid)
# WHERE status='Finished'
# GROUP BY drivers.driverref, constructors.name ORDER BY count(*) DESC
# Out:
# 658 rows affected.
# [('michael_schumacher', 'Ferrari', 141),
#  ('massa', 'Ferrari', 112),
#  ('rosberg', 'Mercedes', 109),
#  ('webber', 'Red Bull', 100),
#  ('vettel', 'Red Bull', 97),
#  ('raikkonen', 'Ferrari', 92),
#  ('button', 'McLaren', 87),
#  ('alonso', 'Ferrari', 87),
#  ('coulthard', 'McLaren', 85),
#  ('hamilton', 'Mercedes', 85),
#  ('hamilton', 'McLaren', 84),
#  ('alonso', 'Renault', 80),
#  ('barrichello', 'Ferrari', 73),
#  ('hakkinen', 'McLaren', 70),
#  ('prost', 'McLaren', 69),
#  ('senna', 'McLaren', 61),
#  ('ricciardo', 'Red Bull', 56),
#  ('ralf_schumacher', 'Williams', 54),
#  ('bottas', 'Williams', 52),
#  ('raikkonen', 'McLaren', 52),
#  ('hulkenberg', 'Force India', 49),
#  ('vettel', 'Ferrari', 48),
#  ('heidfeld', 'BMW Sauber', 47),
#  ('mansell', 'Williams', 46),
#  ('michael_schumacher', 'Benetton', 44),
#  ('damon_hill', 'Williams', 43),
#  ('trulli', 'Toyota', 42),
#  ('massa', 'Williams', 41),
#  ('lauda', 'Ferrari', 40),
#  ('montoya', 'Williams', 39),
#  ('patrese', 'Williams', 39),
#  ('laffite', 'Ligier', 39),
#  ('kubica', 'BMW Sauber', 39),
#  ('perez', 'Force India', 38),
#  ('regazzoni', 'Ferrari', 37),
#  ('piquet', 'Brabham', 36),
#  ('irvine', 'Ferrari', 36),
#  ('rosberg', 'Williams', 36),
#  ('michael_schumacher', 'Mercedes', 34),
#  ('resta', 'Force India', 34),
#  ('fisichella', 'Renault', 33),
#  ('grosjean', 'Lotus F1', 33),
#  ('sutil', 'Force India', 33),
#  ('raikkonen', 'Lotus F1', 33),
#  ('depailler', 'Tyrrell', 32),
#  ('berger', 'Ferrari', 31),
#  ('berger', 'McLaren', 30),
#  ('jones', 'Williams', 29),
#  ('alonso', 'McLaren', 29),
#  ('villeneuve', 'Williams', 28),
#  ('vergne', 'Toro Rosso', 28),
#  ('kobayashi', 'Sauber', 28),
#  ('hill', 'BRM', 27),
#  ('button', 'BAR', 27),
#  ('mario_andretti', 'Team Lotus', 27),
#  ('scheckter', 'Tyrrell', 25),
#  ('alboreto', 'Ferrari', 25),
#  ('stewart', 'Tyrrell', 25),
#  ('alesi', 'Ferrari', 24),
#  ('coulthard', 'Red Bull', 24),
#  ('peterson', 'Team Lotus', 24),
#  ('clark', 'Lotus-Climax', 24),
#  ('gilles_villeneuve', 'Ferrari', 23),
#  ('keke_rosberg', 'Williams', 23),
#  ('kovalainen', 'McLaren', 23),
#  ('mass', 'McLaren', 22),
#  ('mclaren', 'Cooper-Climax', 22),
#  ('ricciardo', 'Toro Rosso', 22),
#  ('ralf_schumacher', 'Toyota', 22),
#  ('max_verstappen', 'Red Bull', 22),
#  ('watson', 'McLaren', 22),
#  ('piquet', 'Williams', 22),
#  ('glock', 'Toyota', 22),
#  ('trulli', 'Renault', 21),
#  ('senna', 'Team Lotus', 21),
#  ('alesi', 'Benetton', 21),
#  ('angelis', 'Team Lotus', 21),
#  ('maldonado', 'Williams', 21),
#  ('berger', 'Benetton', 20),
#  ('hulme', 'McLaren', 20),
#  ('reutemann', 'Williams', 20),
#  ('prost', 'Renault', 20),
#  ('lauda', 'McLaren', 19),
#  ('ickx', 'Ferrari', 19),
#  ('prost', 'Ferrari', 19),
#  ('reutemann', 'Ferrari', 19),
#  ('button', 'Honda', 19),
#  ('emerson_fittipaldi', 'Team Lotus', 19),
#  ('reutemann', 'Brabham', 18),
#  ('buemi', 'Toro Rosso', 18),
#  ('sainz', 'Toro Rosso', 18),
#  ('frentzen', 'Jordan', 18),
#  ('piquet', 'Benetton', 18),
#  ('villeneuve', 'BAR', 18),
#  ('barrichello', 'Honda', 18),
#  ('wurz', 'Benetton', 17),
#  ('cevert', 'Tyrrell', 17),
#  ('frentzen', 'Williams', 17),
#  ('phil_hill', 'Ferrari', 17),
#  ('hunt', 'McLaren', 17),
#  ('ascari', 'Ferrari', 16),
#  ('button', 'Brawn', 16),
#  ('nannini', 'Benetton', 16),
#  ('barrichello', 'Brawn', 16),
#  ('fisichella', 'Benetton', 16),
#  ('emerson_fittipaldi', 'McLaren', 16),
#  ('scheckter', 'Wolf', 15),
#  ('perez', 'Sauber', 15),
#  ('arnoux', 'Renault', 15),
#  ('hawthorn', 'Ferrari', 15),
#  ('nakajima', 'Williams', 15),
#  ('kubica', 'Renault', 14),
#  ('bottas', 'Mercedes', 14),
#  ('barrichello', 'Jordan', 14),
#  ('perez', 'McLaren', 14),
#  ('montoya', 'McLaren', 14),
#  ('barrichello', 'Williams', 14),
#  ('watson', 'Brabham', 14),
#  ('alguersuari', 'Toro Rosso', 14),
#  ('hulme', 'McLaren-Ford', 14),
#  ('petrov', 'Renault', 14),
#  ('boutsen', 'Williams', 14),
#  ('fangio', 'Maserati', 14),
#  ('hulkenberg', 'Sauber', 13),
#  ('mansell', 'Ferrari', 13),
#  ('massa', 'Sauber', 13),
#  ('bruno_senna', 'Williams', 13),
#  ('tambay', 'Ferrari', 13),
#  ('surtees', 'Ferrari', 13),
#  ('fisichella', 'Jordan', 13),
#  ('webber', 'Williams', 13),
#  ('arnoux', 'Ferrari', 13),
#  ('herbert', 'Sauber', 13),
#  ('jack_brabham', 'Brabham-Repco', 13),
#  ('jack_brabham', 'Cooper-Climax', 13),
#  ('revson', 'McLaren', 12),
#  ('kevin_magnussen', 'McLaren', 12),
#  ('liuzzi', 'Force India', 12),
#  ('farina', 'Ferrari', 12),
#  ('vettel', 'Toro Rosso', 12),
#  ('ralf_schumacher', 'Jordan', 11),
#  ('maldonado', 'Lotus F1', 11),
#  ('stewart', 'Matra-Ford', 11),
#  ('kvyat', 'Toro Rosso', 11),
#  ('kovalainen', 'Renault', 11),
#  ('max_verstappen', 'Toro Rosso', 11),
#  ('piquet_jr', 'Renault', 11),
#  ('sato', 'BAR', 11),
#  ('emerson_fittipaldi', 'Fittipaldi', 11),
#  ('coulthard', 'Williams', 11),
#  ('hunt', 'Hesketh', 11),
#  ('prost', 'Williams', 11),
#  ('bourdais', 'Toro Rosso', 11),
#  ('gutierrez', 'Sauber', 11),
#  ('grosjean', 'Haas F1 Team', 11),
#  ('heidfeld', 'Sauber', 10),
#  ('hill', 'Lotus-Ford', 10),
#  ('brundle', 'Benetton', 10),
#  ('gonzalez', 'Ferrari', 10),
#  ('ginther', 'BRM', 10),
#  ('mansell', 'Team Lotus', 10),
#  ('panis', 'Prost', 10),
#  ('irvine', 'Jaguar', 10),
#  ('damon_hill', 'Jordan', 10),
#  ('barrichello', 'Stewart', 10),
#  ('piquet', 'Team Lotus', 9),
#  ('scheckter', 'Ferrari', 9),
#  ('alesi', 'Sauber', 9),
#  ('bandini', 'Ferrari', 9),
#  ('beltoise', 'BRM', 9),
#  ('fangio', 'Mercedes', 9),
#  ('collins', 'Ferrari', 9),
#  ('stewart', 'BRM', 9),
#  ('kvyat', 'Red Bull', 9),
#  ('trulli', 'Jordan', 9),
#  ('nasr', 'Sauber', 9),
#  ('fisichella', 'Sauber', 9),
#  ('webber', 'Jaguar', 8),
#  ('patrese', 'Arrows', 8),
#  ('pironi', 'Tyrrell', 8),
#  ('fisichella', 'Force India', 8),
#  ('ocon', 'Force India', 8),
#  ('panis', 'Ligier', 8),
#  ('klien', 'Red Bull', 8),
#  ('fangio', 'Alfa Romeo', 8),
#  ('pironi', 'Ferrari', 8),
#  ('moss', 'Vanwall', 8),
#  ('boutsen', 'Benetton', 8),
#  ('hulme', 'Brabham-Repco', 8),
#  ('rodriguez', 'BRM', 8),
#  ('frentzen', 'Sauber', 8),
#  ('nilsson', 'Team Lotus', 7),
#  ('ericsson', 'Sauber', 7),
#  ('farina', 'Alfa Romeo', 7),
#  ('reutemann', 'Team Lotus', 7),
#  ('regazzoni', 'Williams', 7),
#  ('gurney', 'Brabham-Climax', 7),
#  ('trips', 'Ferrari', 7),
#  ('gurney', 'Porsche', 7),
#  ('trulli', 'Prost', 7),
#  ('herbert', 'Benetton', 7),
#  ('alboreto', 'Tyrrell', 7),
#  ('hulkenberg', 'Williams', 7),
#  ('jack_brabham', 'Brabham', 7),
#  ('johansson', 'McLaren', 7),
#  ('peterson', 'March', 7),
#  ('patrese', 'Brabham', 7),
#  ('lauda', 'Brabham', 7),
#  ('ginther', 'Ferrari', 6),
#  ('musso', 'Ferrari', 6),
#  ('beltoise', 'Matra', 6),
#  ('warwick', 'Arrows', 6),
#  ('pryce', 'Shadow', 6),
#  ('hailwood', 'Surtees', 6),
#  ('amon', 'Ferrari', 6),
#  ('clark', 'Lotus-Ford', 6),
#  ('johansson', 'Ferrari', 6),
#  ('brambilla', 'March', 6),
#  ('behra', 'Maserati', 6),
#  ('fagioli', 'Alfa Romeo', 6),
#  ('peterson', 'March-Ford', 6),
#  ('villoresi', 'Ferrari', 6),
#  ('fangio', 'Ferrari', 6),
#  ('pironi', 'Ligier', 6),
#  ('jolyon_palmer', 'Renault', 6),
#  ('rosa', 'McLaren', 6),
#  ('jones', 'Shadow', 6),
#  ('pace', 'Brabham', 6),
#  ('button', 'Renault', 6),
#  ('rindt', 'Team Lotus', 5),
#  ('raikkonen', 'Sauber', 5),
#  ('rosa', 'Sauber', 5),
#  ('brooks', 'Vanwall', 5),
#  ('stewart', 'March', 5),
#  ('amon', 'Matra', 5),
#  ('cheever', 'Renault', 5),
#  ('heidfeld', 'Williams', 5),
#  ('parsons', 'Kurtis Kraft', 5),
#  ('nakano', 'Prost', 5),
#  ('laffite', 'Williams', 5),
#  ('paul_russo', 'Kurtis Kraft', 5),
#  ('hill', 'Brabham', 5),
#  ('stuck', 'March', 5),
#  ('tambay', 'McLaren', 5),
#  ('zonta', 'BAR', 5),
#  ('hulkenberg', 'Renault', 5),
#  ('villeneuve', 'BMW Sauber', 5),
#  ('ickx', 'Brabham-Ford', 5),
#  ('ickx', 'Team Lotus', 5),
#  ('watson', 'Penske', 5),
#  ('irvine', 'Jordan', 5),
#  ('panis', 'BAR', 5),
#  ('stommelen', 'Brabham', 5),
#  ('diniz', 'Sauber', 5),
#  ('jarier', 'Tyrrell', 5),
#  ('alesi', 'Tyrrell', 4),
#  ('pace', 'Brabham-Alfa Romeo', 4),
#  ('trintignant', 'Ferrari', 4),
#  ('brundle', 'McLaren', 4),
#  ('wurz', 'Williams', 4),
#  ('jack_brabham', 'Brabham-Climax', 4),
#  ('giacomelli', 'Alfa Romeo', 4),
#  ('brambilla', 'Surtees', 4),
#  ('depailler', 'Ligier', 4),
#  ('mcgrath', 'Kurtis Kraft', 4),
#  ('fisichella', 'Ferrari', 4),
#  ('keke_rosberg', 'McLaren', 4),
#  ('regazzoni', 'Ensign', 4),
#  ('cheever', 'Arrows', 4),
#  ('amon', 'March', 4),
#  ('heidfeld', 'Renault', 4),
#  ('stroll', 'Williams', 4),
#  ('panis', 'Toyota', 4),
#  ('hunt', 'March', 4),
#  ('villeneuve', 'Sauber', 4),
#  ('bonnier', 'Porsche', 4),
#  ('warwick', 'Toleman', 4),
#  ('button', 'Williams', 4),
#  ('capelli', 'March', 4),
#  ('wisell', 'Lotus-Ford', 4),
#  ('warwick', 'Renault', 4),
#  ('jarier', 'Shadow', 4),
#  ('mclaren', 'McLaren-Ford', 4),
#  ('mario_andretti', 'Ferrari', 4),
#  ('gugelmin', 'March', 4),
#  ('chilton', 'Marussia', 4),
#  ('herbert', 'Team Lotus', 4),
#  ('brooks', 'Ferrari', 4),
#  ('moss', 'Lotus-Climax', 4),
#  ('moss', 'Maserati', 4),
#  ('siffert', 'Lotus-Ford', 4),
#  ('pryce', 'Shadow-Ford', 4),
#  ('damon_hill', 'Arrows', 4),
#  ('hanks', 'Kurtis Kraft', 4),
#  ('herbert', 'Stewart', 4),
#  ('ganley', 'BRM', 4),
#  ('cesaris', 'Jordan', 4),
#  ('rindt', 'Cooper-Maserati', 4),
#  ('spence', 'Lotus-Climax', 4),
#  ('brundle', 'Ligier', 3),
#  ('brundle', 'Jordan', 3),
#  ('rindt', 'Lotus-Ford', 3),
#  ('freeland', 'Phillips', 3),
#  ('tambay', 'Renault', 3),
#  ('taruffi', 'Ferrari', 3),
#  ('wilson_fittipaldi', 'Brabham', 3),
#  ('senna', 'Toleman', 3),
#  ('hailwood', 'McLaren', 3),
#  ('surtees', 'Cooper-Climax', 3),
#  ('hakkinen', 'Team Lotus', 3),
#  ('cesaris', 'Alfa Romeo', 3),
#  ('zanardi', 'Williams', 3),
#  ('vandoorne', 'McLaren', 3),
#  ('blundell', 'McLaren', 3),
#  ('liuzzi', 'Toro Rosso', 3),
#  ('verstappen', 'Arrows', 3),
#  ('verstappen', 'Benetton', 3),
#  ('linden', 'Kurtis Kraft', 3),
#  ('beltoise', 'Matra-Ford', 3),
#  ('maggs', 'Cooper-Climax', 3),
#  ('cross', 'Kurtis Kraft', 3),
#  ('salo', 'Ferrari', 3),
#  ('pizzonia', 'Williams', 3),
#  ('modena', 'Tyrrell', 3),
#  ('salo', 'Sauber', 3),
#  ('ireland', 'Team Lotus', 3),
#  ('moss', 'Cooper-Climax', 3),
#  ('stuck', 'Brabham', 3),
#  ('jabouille', 'Renault', 3),
#  ('jack_brabham', 'Brabham-Ford', 3),
#  ('emerson_fittipaldi', 'Lotus-Ford', 3),
#  ('diniz', 'Arrows', 3),
#  ('siffert', 'BRM', 3),
#  ('johnson', 'Kurtis Kraft', 3),
#  ('moss', 'Mercedes', 3),
#  ('moss', 'Team Lotus', 3),
#  ('peterson', 'Tyrrell', 3),
#  ('jules_bianchi', 'Marussia', 3),
#  ('kevin_magnussen', 'Haas F1 Team', 3),
#  ('kevin_magnussen', 'Renault', 3),
#  ('baghetti', 'Ferrari', 3),
#  ('kling', 'Mercedes', 3),
#  ('daywalt', 'Kurtis Kraft', 3),
#  ('kovalainen', 'Caterham', 3),
#  ('schell', 'BRM', 3),
#  ('mario_andretti', 'Parnelli', 3),
#  ('cheever', 'Tyrrell', 3),
#  ('darter', 'Kurtis Kraft', 3),
#  ('oliver', 'Shadow', 3),
#  ('patrese', 'Benetton', 3),
#  ('courage', 'Brabham-Ford', 3),
#  ('surtees', 'Honda', 3),
#  ('garde', 'Caterham', 3),
#  ('gene', 'Williams', 3),
#  ('giacomelli', 'Toleman', 3),
#  ('agabashian', 'Kurtis Kraft', 2),
#  ('alesi', 'Prost', 2),
#  ('arnoux', 'Ligier', 2),
#  ('bernard', 'Larrousse', 2),
#  ('bettenhausen', 'Epperly', 2),
#  ('blundell', 'Ligier', 2),
#  ('bonnier', 'BRM', 2),
#  ('boyd', 'Kurtis Kraft', 2),
#  ('brooks', 'BRM', 2),
#  ('bruno_senna', 'Renault', 2),
#  ('bryan', 'Kuzma', 2),
#  ('button', 'Benetton', 2),
#  ('capelli', 'Leyton House', 2),
#  ('castellotti', 'Ferrari', 2),
#  ('cheever', 'Ligier', 2),
#  ('connor', 'Kurtis Kraft', 2),
#  ('daly', 'Ensign', 2),
#  ('daly', 'Williams', 2),
#  ('davies', 'Kurtis Kraft', 2),
#  ('fabi', 'Brabham', 2),
#  ('fischer', 'Ferrari', 2),
#  ('frere', 'Ferrari', 2),
#  ('gachot', 'Jordan', 2),
#  ('gendebien', 'Ferrari', 2),
#  ('gene', 'Minardi', 2),
#  ('gethin', 'BRM', 2),
#  ('glock', 'Marussia', 2),
#  ('goldsmith', 'Epperly', 2),
#  ('gonzalez', 'Maserati', 2),
#  ('gurney', 'Brabham', 2),
#  ('gurney', 'Eagle-Weslake', 2),
#  ('gurney', 'Ferrari', 2),
#  ('gutierrez', 'Haas F1 Team', 2),
#  ('ireland', 'Lotus-Climax', 2),
#  ('klien', 'Jaguar', 2),
#  ('kobayashi', 'Toyota', 2),
#  ('lehto', 'Dallara', 2),
#  ('lewis', 'Cooper-Climax', 2),
#  ('lewis-evans', 'Vanwall', 2),
#  ('liuzzi', 'Red Bull', 2),
#  ('mario_andretti', 'Alfa Romeo', 2),
#  ('mass', 'Arrows', 2),
#  ('matta', 'Toyota', 2),
#  ('merzario', 'Iso Marlboro', 2),
#  ('morbidelli', 'Sauber', 2),
#  ('moreno', 'Benetton', 2),
#  ('musso', 'Maserati', 2),
#  ('nazaruk', 'Kurtis Kraft', 2),
#  ('oliver', 'Lotus-Ford', 2),
#  ('pace', 'Surtees', 2),
#  ('parkes', 'Ferrari', 2),
#  ('pescarolo', 'Matra', 2),
#  ('petrov', 'Caterham', 2),
#  ('pic', 'Caterham', 2),
#  ('pic', 'Marussia', 2),
#  ('rathmann', 'Epperly', 2),
#  ('rathmann', 'Kurtis Kraft', 2),
#  ('rathmann', 'Watson', 2),
#  ('rebaque', 'Brabham', 2),
#  ('redman', 'McLaren', 2),
#  ('regazzoni', 'BRM', 2),
#  ('ricardo_rodriguez', 'Ferrari', 2),
#  ('rindt', 'Brabham-Repco', 2),
#  ('rosa', 'Arrows', 2),
#  ('salo', 'Toyota', 2),
#  ('salo', 'Tyrrell', 2),
#  ('salvadori', 'Cooper', 2),
#  ('salvadori', 'Cooper-Climax', 2),
#  ('satoru_nakajima', 'Team Lotus', 2),
#  ('schell', 'Maserati', 2),
#  ('schenken', 'Brabham', 2),
#  ('siffert', 'Brabham-BRM', 2),
#  ('surtees', 'Cooper-Maserati', 2),
#  ('surtees', 'Lola', 2),
#  ('surtees', 'Surtees', 2),
#  ('sutil', 'Sauber', 2),
#  ('suzuki', 'Larrousse', 2),
#  ('tambay', 'Ensign', 2),
#  ('thomson', 'Lesovsky', 2),
#  ('trintignant', 'Cooper', 2),
#  ('trintignant', 'Cooper-Climax', 2),
#  ('vukovich', 'Kurtis Kraft', 2),
#  ('ward', 'Watson', 2),
#  ('lauda', 'BRM', 1),
#  ('larson', 'Watson', 1),
#  ('larini', 'Sauber', 1),
#  ('larini', 'Ferrari', 1),
#  ('lamy', 'Minardi', 1),
#  ('perdisa', 'Maserati', 1),
#  ('kovalainen', 'Lotus F1', 1),
#  ('kovalainen', 'Lotus', 1),
#  ('kobayashi', 'Caterham', 1),
#  ('pescarolo', 'BRM', 1),
#  ('pescarolo', 'Iso Marlboro', 1),
#  ('pescarolo', 'March-Ford', 1),
#  ('beaufort', 'Porsche', 1),
#  ('keller', 'Kurtis Kraft', 1),
#  ('keke_rosberg', 'Fittipaldi', 1),
#  ('katayama', 'Tyrrell', 1),
#  ('jones', 'Surtees', 1),
#  ('barth', 'Porsche', 1),
#  ('jones', 'Embassy Hill', 1),
#  ('johnson', 'Trevis', 1),
#  ('banks', 'Moore', 1),
#  ('ball', 'Schroeder', 1),
#  ('johansson', 'Onyx', 1),
#  ('jarier', 'Shadow-Ford', 1),
#  ('piquet', 'McLaren', 1),
#  ('jarier', 'Penske', 1),
#  ('jarier', 'Ligier', 1),
#  ('james', 'Kurtis Kraft', 1),
#  ('jack_brabham', 'Cooper', 1),
#  ('jabouille', 'Tyrrell', 1),
#  ('ickx', 'McLaren', 1),
#  ('pirro', 'Dallara', 1),
#  ('ickx', 'Ensign', 1),
#  ('hulme', 'Brabham-Climax', 1),
#  ('hoyt', 'Kurtis Kraft', 1),
#  ('homeier', 'Kuzma', 1),
#  ('homeier', 'Kurtis Kraft', 1),
#  ('hill', 'Shadow', 1),
#  ('hill', 'Lola', 1),
#  ('herman', 'Kurtis Kraft', 1),
#  ('herman', 'Dunn', 1),
#  ('herbert', 'Jaguar', 1),
#  ('hartley', 'Lesovsky', 1),
#  ('hartley', 'Kuzma', 1),
#  ('hanks', 'Epperly', 1),
#  ('hahne', 'Lola', 1),
#  ('alboreto', 'Footwork', 1),
#  ('wallard', 'Kurtis Kraft', 1),
#  ('ward', 'Kurtis Kraft', 1),
#  ('zonta', 'Toyota', 1),
#  ('rebaque', 'Team Lotus', 1),
#  ('baldi', 'Alfa Romeo', 1),
#  ('reece', 'Kurtis Kraft', 1),
#  ('reece', 'Lesovsky', 1),
#  ('reece', 'Watson', 1),
#  ('rees', 'Brabham-Ford', 1),
#  ('reg_parnell', 'Alfa Romeo', 1),
#  ('badoer', 'Ferrari', 1),
#  ('gurney', 'McLaren-Ford', 1),
#  ('gugelmin', 'Leyton House', 1),
#  ('grosjean', 'Renault', 1),
#  ('griffith', 'Kurtis Kraft', 1),
#  ('gregory', 'Maserati', 1),
#  ('gregory', 'Cooper-Climax', 1),
#  ('giunti', 'Ferrari', 1),
#  ('ginther', 'Honda', 1),
#  ('george_connor', 'Kurtis Kraft', 1),
#  ('warwick', 'Team Lotus', 1),
#  ('george_amick', 'Epperly', 1),
#  ('gendebien', 'Cooper-Climax', 1),
#  ('rigsby', 'Watson', 1),
#  ('ayulo', 'Kurtis Kraft', 1),
#  ('rindt', 'Cooper-Climax', 1),
#  ('gavin', 'Matra-Ford', 1),
#  ('frentzen', 'Arrows', 1),
#  ('foyt', 'Kuzma', 1),
#  ('follmer', 'Shadow', 1),
#  ('rodriguez', 'Cooper-Maserati', 1),
#  ('attwood', 'Lotus-Ford', 1),
#  ('rosa', 'HRT', 1),
#  ('rosa', 'Jaguar', 1),
#  ('flockhart', 'BRM', 1),
#  ('flaherty', 'Watson', 1),
#  ('flaherty', 'Kurtis Kraft', 1),
#  ('fittipaldi', 'Footwork', 1),
#  ('rosier', 'Talbot-Lago', 1),
#  ('rossi', 'Manor Marussia', 1),
#  ('ruby', 'Watson', 1),
#  ('ruttman', 'Kurtis Kraft', 1),
#  ('ruttman', 'Kuzma', 1),
#  ('faulkner', 'Kurtis Kraft', 1),
#  ('salo', 'Arrows', 1),
#  ('ertl', 'Hesketh', 1),
#  ('ericsson', 'Caterham', 1),
#  ('attwood', 'BRM', 1),
#  ('ascari', 'Alfa Romeo', 1),
#  ('watson', 'Surtees', 1),
#  ('arundell', 'Lotus-Climax', 1),
#  ('donohue', 'Penske', 1),
#  ('sato', 'Jordan', 1),
#  ('sato', 'Super Aguri', 1),
#  ('arnold', 'Kurtis Kraft', 1),
#  ('satoru_nakajima', 'Tyrrell', 1),
#  ('scarfiotti', 'Ferrari', 1),
#  ('donohue', 'McLaren', 1),
#  ('donnelly', 'Team Lotus', 1),
#  ('dick_rathmann', 'Kurtis Kraft', 1),
#  ('davidson', 'Super Aguri', 1),
#  ('angelis', 'Shadow', 1),
#  ('wehrlein', 'Manor Marussia', 1),
#  ('schenken', 'Surtees', 1),
#  ('schindler', 'Stevens', 1),
#  ('darter', 'Lesovsky', 1),
#  ('darter', 'Kuzma', 1),
#  ('daly', 'Tyrrell', 1),
#  ('serafini', 'Ferrari', 1),
#  ('crockett', 'Kurtis Kraft', 1),
#  ('wehrlein', 'Sauber', 1),
#  ('siffert', 'Lotus-Climax', 1),
#  ('courage', 'BRM', 1),
#  ('speed', 'Toro Rosso', 1),
#  ('comas', 'Ligier', 1),
#  ('comas', 'Larrousse', 1),
#  ('clark', 'Team Lotus', 1),
#  ('clark', 'Lotus-BRM', 1),
#  ('christie', 'Kurtis Kraft', 1),
#  ('cheesbourg', 'Kurtis Kraft', 1),
#  ('stommelen', 'Brabham-Alfa Romeo', 1),
#  ('stommelen', 'Embassy Hill', 1),
#  ('stommelen', 'Surtees', 1),
#  ('streiff', 'Ligier', 1),
#  ('cevert', 'March', 1),
#  ('stuck', 'ATS', 1),
#  ('cesaris', 'McLaren', 1),
#  ('cesaris', 'Dallara', 1),
#  ('surer', 'Arrows', 1),
#  ('surer', 'Brabham', 1),
#  ('surer', 'Ensign', 1),
#  ('castellotti', 'Lancia', 1),
#  ('wendlinger', 'Sauber', 1),
#  ('caffi', 'Dallara', 1),
#  ('burgess', 'Cooper-Climax', 1),
#  ('amick', 'Epperly', 1),
#  ('ambrosio', 'Lotus F1', 1),
#  ('surtees', 'Team Lotus', 1),
#  ('burgess', 'Cooper', 1),
#  ('wisell', 'Team Lotus', 1),
#  ('sutil', 'Spyker', 1),
#  ('allison', 'Team Lotus', 1),
#  ('sweikert', 'Kurtis Kraft', 1),
#  ('sweikert', 'Kuzma', 1),
#  ('takagi', 'Arrows', 1),
#  ('wurz', 'McLaren', 1),
#  ('bryan', 'Kurtis Kraft', 1),
#  ('bryan', 'Epperly', 1),
#  ('brise', 'Embassy Hill', 1),
#  ('branson', 'Phillips', 1),
#  ('taruffi', 'Mercedes', 1),
#  ('teague', 'Kurtis Kraft', 1),
#  ('thomson', 'Kuzma', 1),
#  ('allison', 'Ferrari', 1),
#  ('tingelstad', 'Trevis', 1),
#  ('tolan', 'Kuzma', 1),
#  ('trevor_taylor', 'Lotus-Climax', 1),
#  ('zanardi', 'Jordan', 1),
#  ('alesi', 'Jordan', 1),
#  ('boyd', 'Epperly', 1),
#  ('boutsen', 'Ligier', 1),
#  ('boutsen', 'Arrows', 1),
#  ('trulli', 'Lotus', 1),
#  ('bonnier', 'Cooper-Maserati', 1),
#  ('bonnier', 'Brabham-Climax', 1),
#  ('bonetto', 'Maserati', 1),
#  ('turner', 'Kurtis Kraft', 1),
#  ('blundell', 'Tyrrell', 1),
#  ('veith', 'Kurtis Kraft', 1),
#  ('veith', 'Meskowski', 1),
#  ('veith', 'Moore', 1),
#  ('veith', 'Phillips', 1),
#  ('blundell', 'Brabham', 1),
#  ('beuttler', 'March', 1),
#  ('modena', 'Brabham', 1),
#  ('monteiro', 'Jordan', 1),
#  ('mitter', 'Porsche', 1),
#  ('miles', 'Team Lotus', 1),
#  ('morbidelli', 'Ferrari', 1),
#  ('morbidelli', 'Footwork', 1),
#  ('bettenhausen', 'Kurtis Kraft', 1),
#  ('verstappen', 'Footwork', 1),
#  ('moss', 'BRM', 1),
#  ('moss', 'Cooper', 1),
#  ('merzario', 'March', 1),
#  ('merzario', 'Ferrari', 1),
#  ('menditeguy', 'Cooper-Maserati', 1),
#  ('mcwithey', 'Kurtis Kraft', 1),
#  ('mcnish', 'Toyota', 1),
#  ('mclaren', 'Cooper', 1),
#  ('mccoy', 'Stevens', 1),
#  ('vettel', 'BMW Sauber', 1),
#  ('mazzacane', 'Minardi', 1),
#  ('mass', 'Surtees', 1),
#  ('mass', 'ATS', 1),
#  ('martini', 'Minardi', 1),
#  ('bernard', 'Ligier', 1),
#  ('niday', 'Stevens', 1),
#  ('marsh', 'Cooper', 1),
#  ('manzon', 'Gordini', 1),
#  ('ocon', 'Manor Marussia', 1),
#  ('bellof', 'Tyrrell', 1),
#  ('oliver', 'McLaren', 1),
#  ('mantovani', 'Maserati', 1),
#  ('mairesse', 'Ferrari', 1),
#  ('magnussen', 'Stewart', 1),
#  ('bell', 'Surtees', 1),
#  ('love', 'Cooper-Climax', 1),
#  ('lombardi', 'March', 1),
#  ('linden', 'Sherman', 1),
#  ('lennep', 'Ensign', 1),
#  ('behra', 'BRM', 1),
#  ('lauda', 'Brabham-Alfa Romeo', 1)]

# %% [markdown]
# ## 4) Create a third (and new) query that finds the amount of milliseconds spent in pitstop (see the `pitstops` relation) by each unique combinations of `driverid` and `raceid`.

# %%
# %%sql CREATE OR REPLACE VIEW ms_pitstops AS
# SELECT drivers.driverid, pitstops.raceid, drivers.driverref, SUM(pitstops.milliseconds) AS pitstop_total_ms FROM drivers
# JOIN pitstops on pitstops.driverid = drivers.driverid
# GROUP BY drivers.driverid, pitstops.raceid
# ORDER BY sum(pitstops.milliseconds) DESC;
# Out:
# Done.
# []

# %%
# %sql SELECT * FROM ms_pitstops;
# Out:
# 2699 rows affected.
# [(817, 967, 'ricciardo', Decimal('3572090')),
#  (18, 967, 'button', Decimal('3569001')),
#  (830, 967, 'max_verstappen', Decimal('3563738')),
#  (13, 967, 'massa', Decimal('3554774')),
#  (826, 967, 'kvyat', Decimal('3546767')),
#  (825, 967, 'kevin_magnussen', Decimal('3542704')),
#  (822, 967, 'bottas', Decimal('3542270')),
#  (821, 967, 'gutierrez', Decimal('3538573')),
#  (20, 967, 'vettel', Decimal('3524541')),
#  (836, 967, 'wehrlein', Decimal('3518952')),
#  (807, 967, 'hulkenberg', Decimal('3518090')),
#  (4, 967, 'alonso', Decimal('3517428')),
#  (839, 967, 'ocon', Decimal('3494144')),
#  (1, 967, 'hamilton', Decimal('3492409')),
#  (832, 967, 'sainz', Decimal('3491881')),
#  (831, 967, 'nasr', Decimal('3491420')),
#  (3, 967, 'rosberg', Decimal('3491371')),
#  (815, 967, 'perez', Decimal('3490688')),
#  (815, 976, 'perez', Decimal('1645436')),
#  (8, 976, 'raikkonen', Decimal('1637077')),
#  (836, 976, 'wehrlein', Decimal('1426360')),
#  (154, 976, 'grosjean', Decimal('1395069')),
#  (822, 976, 'bottas', Decimal('1385158')),
#  (839, 976, 'ocon', Decimal('1381084')),
#  (20, 976, 'vettel', Decimal('1375358')),
#  (1, 976, 'hamilton', Decimal('1373445')),
#  (817, 976, 'ricciardo', Decimal('1372037')),
#  (838, 976, 'vandoorne', Decimal('1371155')),
#  (828, 976, 'ericsson', Decimal('1364907')),
#  (840, 976, 'stroll', Decimal('1350680')),
#  (807, 976, 'hulkenberg', Decimal('1350542')),
#  (832, 976, 'sainz', Decimal('1349699')),
#  (4, 976, 'alonso', Decimal('1349508')),
#  (825, 976, 'kevin_magnussen', Decimal('1348223')),
#  (13, 976, 'massa', Decimal('1347157')),
#  (8, 914, 'raikkonen', Decimal('1241874')),
#  (825, 914, 'kevin_magnussen', Decimal('1241718')),
#  (155, 914, 'kobayashi', Decimal('1238155')),
#  (154, 914, 'grosjean', Decimal('1228877')),
#  (18, 914, 'button', Decimal('1213890')),
#  (815, 914, 'perez', Decimal('1210618')),
#  (807, 914, 'hulkenberg', Decimal('1209923')),
#  (826, 914, 'kvyat', Decimal('1209872')),
#  (16, 914, 'sutil', Decimal('1209654')),
#  (813, 914, 'maldonado', Decimal('1202770')),
#  (828, 914, 'ericsson', Decimal('1196670')),
#  (820, 914, 'chilton', Decimal('1187094')),
#  (822, 914, 'bottas', Decimal('1186511')),
#  (821, 914, 'gutierrez', Decimal('1186369')),
#  (818, 914, 'vergne', Decimal('1186361')),
#  (13, 914, 'massa', Decimal('1185898')),
#  (817, 914, 'ricciardo', Decimal('1185311')),
#  (3, 914, 'rosberg', Decimal('1185074')),
#  (1, 914, 'hamilton', Decimal('1184863')),
#  (824, 914, 'jules_bianchi', Decimal('1183734')),
#  (20, 914, 'vettel', Decimal('1182185')),
#  (830, 948, 'max_verstappen', Decimal('1140741')),
#  (4, 914, 'alonso', Decimal('1137051')),
#  (20, 948, 'vettel', Decimal('1135199')),
#  (832, 948, 'sainz', Decimal('1134777')),
#  (817, 948, 'ricciardo', Decimal('1134048')),
#  (836, 948, 'wehrlein', Decimal('1132241')),
#  (18, 948, 'button', Decimal('1128919')),
#  (828, 948, 'ericsson', Decimal('1126168')),
#  (815, 948, 'perez', Decimal('1112030')),
#  (1, 948, 'hamilton', Decimal('1112027')),
#  (8, 948, 'raikkonen', Decimal('1111873')),
#  (835, 948, 'jolyon_palmer', Decimal('1111580')),
#  (13, 948, 'massa', Decimal('1111355')),
#  (807, 948, 'hulkenberg', Decimal('1111322')),
#  (3, 948, 'rosberg', Decimal('1110834')),
#  (822, 948, 'bottas', Decimal('1110365')),
#  (831, 948, 'nasr', Decimal('1105038')),
#  (154, 948, 'grosjean', Decimal('1089417')),
#  (8, 960, 'raikkonen', Decimal('1076359')),
#  (830, 960, 'max_verstappen', Decimal('1075739')),
#  (835, 960, 'jolyon_palmer', Decimal('1068843')),
#  (831, 960, 'nasr', Decimal('1057826')),
#  (839, 960, 'ocon', Decimal('1053906')),
#  (1, 960, 'hamilton', Decimal('1047253')),
#  (826, 960, 'kvyat', Decimal('1047188')),
#  (815, 960, 'perez', Decimal('1046719')),
#  (154, 960, 'grosjean', Decimal('1046178')),
#  (807, 960, 'hulkenberg', Decimal('1046047')),
#  (821, 960, 'gutierrez', Decimal('1045669')),
#  (13, 960, 'massa', Decimal('1045663')),
#  (20, 960, 'vettel', Decimal('1043676')),
#  (822, 960, 'bottas', Decimal('1042836')),
#  (817, 853, 'ricciardo', Decimal('1035495')),
#  (817, 960, 'ricciardo', Decimal('1020932')),
#  (4, 960, 'alonso', Decimal('1020685')),
#  (3, 960, 'rosberg', Decimal('1018746')),
#  (825, 948, 'kevin_magnussen', Decimal('996228')),
#  (831, 961, 'nasr', Decimal('874834')),
#  (817, 901, 'ricciardo', Decimal('227990')),
#  (828, 982, 'ericsson', Decimal('219000')),
#  (807, 982, 'hulkenberg', Decimal('210176')),
#  (836, 982, 'wehrlein', Decimal('209772')),
#  (17, 888, 'webber', Decimal('201954')),
#  (839, 962, 'ocon', Decimal('201708')),
#  (13, 982, 'massa', Decimal('184389')),
#  (825, 982, 'kevin_magnussen', Decimal('175128')),
#  (839, 982, 'ocon', Decimal('172632')),
#  (814, 881, 'resta', Decimal('166837')),
#  (813, 929, 'maldonado', Decimal('162130')),
#  (822, 962, 'bottas', Decimal('153714')),
#  (24, 844, 'liuzzi', Decimal('149973')),
#  (838, 982, 'vandoorne', Decimal('149174')),
#  (1, 854, 'hamilton', Decimal('148522')),
#  (18, 881, 'button', Decimal('148309')),
#  (16, 894, 'sutil', Decimal('143408')),
#  (831, 942, 'nasr', Decimal('143303')),
#  (835, 982, 'jolyon_palmer', Decimal('142157')),
#  (18, 847, 'button', Decimal('141067')),
#  (24, 854, 'liuzzi', Decimal('141058')),
#  (815, 982, 'perez', Decimal('140626')),
#  (828, 957, 'ericsson', Decimal('140373')),
#  (826, 953, 'kvyat', Decimal('140225')),
#  (817, 982, 'ricciardo', Decimal('138277')),
#  (8, 936, 'raikkonen', Decimal('138104')),
#  (808, 873, 'petrov', Decimal('138048')),
#  (16, 884, 'sutil', Decimal('136854')),
#  (807, 884, 'hulkenberg', Decimal('135005')),
#  (811, 854, 'bruno_senna', Decimal('134073')),
#  (18, 861, 'button', Decimal('133730')),
#  (18, 939, 'button', Decimal('133245')),
#  (154, 893, 'grosjean', Decimal('133004')),
#  (4, 934, 'alonso', Decimal('132474')),
#  (154, 950, 'grosjean', Decimal('129804')),
#  (5, 879, 'kovalainen', Decimal('129292')),
#  (1, 936, 'hamilton', Decimal('127687')),
#  (813, 847, 'maldonado', Decimal('127508')),
#  (16, 881, 'sutil', Decimal('127234')),
#  (835, 957, 'jolyon_palmer', Decimal('126967')),
#  (154, 982, 'grosjean', Decimal('126052')),
#  (824, 902, 'jules_bianchi', Decimal('125723')),
#  (816, 847, 'ambrosio', Decimal('124547')),
#  (826, 975, 'kvyat', Decimal('124462')),
#  (815, 913, 'perez', Decimal('124109')),
#  (13, 854, 'massa', Decimal('124102')),
#  (815, 970, 'perez', Decimal('123019')),
#  (22, 851, 'barrichello', Decimal('122572')),
#  (1, 950, 'hamilton', Decimal('122126')),
#  (840, 982, 'stroll', Decimal('121693')),
#  (825, 953, 'kevin_magnussen', Decimal('121514')),
#  (13, 970, 'massa', Decimal('121113')),
#  (824, 893, 'jules_bianchi', Decimal('121060')),
#  (828, 934, 'ericsson', Decimal('120490')),
#  (24, 851, 'liuzzi', Decimal('119441')),
#  (823, 883, 'garde', Decimal('119301')),
#  (1, 851, 'hamilton', Decimal('119200')),
#  (813, 902, 'maldonado', Decimal('118958')),
#  (816, 851, 'ambrosio', Decimal('118572')),
#  (813, 913, 'maldonado', Decimal('118014')),
#  (155, 854, 'kobayashi', Decimal('117650')),
#  (813, 936, 'maldonado', Decimal('117642')),
#  (819, 881, 'pic', Decimal('116660')),
#  (815, 936, 'perez', Decimal('116190')),
#  (807, 970, 'hulkenberg', Decimal('115751')),
#  (5, 861, 'kovalainen', Decimal('115691')),
#  (832, 982, 'sainz', Decimal('115590')),
#  (828, 962, 'ericsson', Decimal('114989')),
#  (832, 962, 'sainz', Decimal('114516')),
#  (13, 962, 'massa', Decimal('114092')),
#  (154, 970, 'grosjean', Decimal('112596')),
#  (817, 962, 'ricciardo', Decimal('112398')),
#  (830, 962, 'max_verstappen', Decimal('112357')),
#  (817, 854, 'ricciardo', Decimal('112010')),
#  (8, 962, 'raikkonen', Decimal('112004')),
#  (817, 936, 'ricciardo', Decimal('111897')),
#  (817, 879, 'ricciardo', Decimal('110360')),
#  (1, 962, 'hamilton', Decimal('110339')),
#  (822, 982, 'bottas', Decimal('110332')),
#  (831, 927, 'nasr', Decimal('110194')),
#  (5, 851, 'kovalainen', Decimal('109988')),
#  (37, 873, 'rosa', Decimal('109768')),
#  (154, 936, 'grosjean', Decimal('109662')),
#  (13, 887, 'massa', Decimal('109162')),
#  (833, 936, 'merhi', Decimal('108958')),
#  (822, 936, 'bottas', Decimal('108856')),
#  (839, 970, 'ocon', Decimal('108812')),
#  (821, 887, 'gutierrez', Decimal('108394')),
#  (807, 949, 'hulkenberg', Decimal('108190')),
#  (1, 982, 'hamilton', Decimal('107613')),
#  (807, 956, 'hulkenberg', Decimal('107270')),
#  (821, 907, 'gutierrez', Decimal('106819')),
#  (811, 861, 'bruno_senna', Decimal('106079')),
#  (4, 945, 'alonso', Decimal('105741')),
#  (13, 936, 'massa', Decimal('104994')),
#  (39, 879, 'karthikeyan', Decimal('104957')),
#  (22, 841, 'barrichello', Decimal('104700')),
#  (831, 936, 'nasr', Decimal('104214')),
#  (828, 936, 'ericsson', Decimal('104000')),
#  (829, 936, 'stevens', Decimal('103949')),
#  (807, 950, 'hulkenberg', Decimal('103910')),
#  (813, 851, 'maldonado', Decimal('103850')),
#  (814, 849, 'resta', Decimal('103374')),
#  (17, 851, 'webber', Decimal('103364')),
#  (3, 936, 'rosberg', Decimal('102771')),
#  (37, 879, 'rosa', Decimal('102245')),
#  (13, 903, 'massa', Decimal('102107')),
#  (830, 936, 'max_verstappen', Decimal('101910')),
#  (39, 863, 'karthikeyan', Decimal('101834')),
#  (828, 929, 'ericsson', Decimal('101249')),
#  (831, 953, 'nasr', Decimal('101108')),
#  (3, 879, 'rosberg', Decimal('100854')),
#  (18, 962, 'button', Decimal('100838')),
#  (4, 936, 'alonso', Decimal('100704')),
#  (15, 847, 'trulli', Decimal('100156')),
#  (13, 867, 'massa', Decimal('100141')),
#  (1, 844, 'hamilton', Decimal('99637')),
#  (826, 936, 'kvyat', Decimal('99611')),
#  (825, 970, 'kevin_magnussen', Decimal('99165')),
#  (67, 847, 'buemi', Decimal('99129')),
#  (813, 927, 'maldonado', Decimal('98959')),
#  (820, 913, 'chilton', Decimal('98603')),
#  (20, 861, 'vettel', Decimal('98597')),
#  (13, 847, 'massa', Decimal('98534')),
#  (13, 861, 'massa', Decimal('98518')),
#  (819, 861, 'pic', Decimal('98083')),
#  (4, 842, 'alonso', Decimal('98040')),
#  (823, 893, 'garde', Decimal('98002')),
#  (823, 886, 'garde', Decimal('97928')),
#  (155, 873, 'kobayashi', Decimal('97681')),
#  (20, 970, 'vettel', Decimal('97435')),
#  (820, 881, 'chilton', Decimal('97419')),
#  (813, 884, 'maldonado', Decimal('97133')),
#  (3, 861, 'rosberg', Decimal('97080')),
#  (826, 978, 'kvyat', Decimal('97063')),
#  (67, 854, 'buemi', Decimal('96960')),
#  (832, 942, 'sainz', Decimal('96681')),
#  (820, 905, 'chilton', Decimal('96563')),
#  (822, 893, 'bottas', Decimal('96418')),
#  (817, 861, 'ricciardo', Decimal('96267')),
#  (815, 844, 'perez', Decimal('96245')),
#  (22, 847, 'barrichello', Decimal('96114')),
#  (817, 857, 'ricciardo', Decimal('96077')),
#  (20, 916, 'vettel', Decimal('95882')),
#  (807, 873, 'hulkenberg', Decimal('95577')),
#  (818, 884, 'vergne', Decimal('95545')),
#  (15, 854, 'trulli', Decimal('95533')),
#  (820, 883, 'chilton', Decimal('95442')),
#  (819, 893, 'pic', Decimal('95395')),
#  (24, 847, 'liuzzi', Decimal('95377')),
#  (818, 913, 'vergne', Decimal('95226')),
#  (5, 863, 'kovalainen', Decimal('95182')),
#  (5, 854, 'kovalainen', Decimal('95030')),
#  (10, 852, 'glock', Decimal('94931')),
#  (821, 883, 'gutierrez', Decimal('94783')),
#  (824, 881, 'jules_bianchi', Decimal('94653')),
#  (832, 939, 'sainz', Decimal('94597')),
#  (813, 861, 'maldonado', Decimal('94539')),
#  (824, 883, 'jules_bianchi', Decimal('94400')),
#  (30, 847, 'michael_schumacher', Decimal('94369')),
#  (808, 867, 'petrov', Decimal('94157')),
#  (16, 847, 'sutil', Decimal('93989')),
#  (823, 881, 'garde', Decimal('93820')),
#  (13, 844, 'massa', Decimal('93500')),
#  (20, 879, 'vettel', Decimal('93201')),
#  (24, 842, 'liuzzi', Decimal('93192')),
#  (813, 891, 'maldonado', Decimal('93181')),
#  (10, 879, 'glock', Decimal('93053')),
#  (1, 842, 'hamilton', Decimal('93011')),
#  (829, 934, 'stevens', Decimal('92825')),
#  (13, 883, 'massa', Decimal('92713')),
#  (808, 851, 'petrov', Decimal('92688')),
#  (818, 881, 'vergne', Decimal('92556')),
#  (30, 879, 'michael_schumacher', Decimal('92536')),
#  (22, 845, 'barrichello', Decimal('92449')),
#  (13, 931, 'massa', Decimal('92299')),
#  (825, 901, 'kevin_magnussen', Decimal('92192')),
#  (17, 854, 'webber', Decimal('92079')),
#  (30, 844, 'michael_schumacher', Decimal('92065')),
#  (808, 854, 'petrov', Decimal('91917')),
#  (821, 881, 'gutierrez', Decimal('91908')),
#  (18, 863, 'button', Decimal('91845')),
#  (4, 982, 'alonso', Decimal('91832')),
#  (811, 873, 'bruno_senna', Decimal('91829')),
#  (815, 974, 'perez', Decimal('91824')),
#  (813, 873, 'maldonado', Decimal('91755')),
#  (818, 879, 'vergne', Decimal('91701')),
#  (20, 854, 'vettel', Decimal('91628')),
#  (814, 846, 'resta', Decimal('91556')),
#  (813, 854, 'maldonado', Decimal('91552')),
#  (3, 847, 'rosberg', Decimal('91528')),
#  (819, 860, 'pic', Decimal('91375')),
#  (826, 913, 'kvyat', Decimal('91369')),
#  (820, 893, 'chilton', Decimal('91357')),
#  (822, 970, 'bottas', Decimal('91270')),
#  (813, 845, 'maldonado', Decimal('91161')),
#  (16, 893, 'sutil', Decimal('91074')),
#  (836, 978, 'wehrlein', Decimal('91052')),
#  (22, 852, 'barrichello', Decimal('91049')),
#  (4, 854, 'alonso', Decimal('90980')),
#  (13, 873, 'massa', Decimal('90816')),
#  (5, 873, 'kovalainen', Decimal('90771')),
#  (813, 893, 'maldonado', Decimal('90585')),
#  (807, 881, 'hulkenberg', Decimal('90522')),
#  (818, 893, 'vergne', Decimal('90449')),
#  (18, 854, 'button', Decimal('90395')),
#  (824, 884, 'jules_bianchi', Decimal('90384')),
#  (820, 880, 'chilton', Decimal('90350')),
#  (16, 913, 'sutil', Decimal('90307')),
#  (4, 957, 'alonso', Decimal('90109')),
#  (834, 942, 'rossi', Decimal('90080')),
#  (824, 913, 'jules_bianchi', Decimal('90050')),
#  (807, 913, 'hulkenberg', Decimal('89764')),
#  (1, 913, 'hamilton', Decimal('89746')),
#  (8, 934, 'raikkonen', Decimal('89549')),
#  (3, 854, 'rosberg', Decimal('89227')),
#  (1, 881, 'hamilton', Decimal('89218')),
#  (8, 913, 'raikkonen', Decimal('89060')),
#  (813, 939, 'maldonado', Decimal('88981')),
#  (828, 939, 'ericsson', Decimal('88844')),
#  (17, 842, 'webber', Decimal('88793')),
#  (814, 847, 'resta', Decimal('88776')),
#  (817, 952, 'ricciardo', Decimal('88658')),
#  (836, 951, 'wehrlein', Decimal('88584')),
#  (153, 844, 'alguersuari', Decimal('88456')),
#  (825, 957, 'kevin_magnussen', Decimal('88455')),
#  (154, 913, 'grosjean', Decimal('88123')),
#  (13, 957, 'massa', Decimal('87992')),
#  (17, 873, 'webber', Decimal('87985')),
#  (18, 883, 'button', Decimal('87913')),
#  (15, 857, 'trulli', Decimal('87778')),
#  (13, 893, 'massa', Decimal('87749')),
#  (815, 843, 'perez', Decimal('87615')),
#  (37, 864, 'rosa', Decimal('87424')),
#  (153, 854, 'alguersuari', Decimal('87083')),
#  (13, 851, 'massa', Decimal('87041')),
#  (821, 962, 'gutierrez', Decimal('86986')),
#  (2, 844, 'heidfeld', Decimal('86975')),
#  (828, 953, 'ericsson', Decimal('86953')),
#  (4, 883, 'alonso', Decimal('86803')),
#  (4, 913, 'alonso', Decimal('86713')),
#  (30, 849, 'michael_schumacher', Decimal('86644')),
#  (823, 885, 'garde', Decimal('86638')),
#  (13, 881, 'massa', Decimal('86569')),
#  (825, 956, 'kevin_magnussen', Decimal('86484')),
#  (3, 881, 'rosberg', Decimal('86423')),
#  (5, 869, 'kovalainen', Decimal('86407')),
#  (808, 844, 'petrov', Decimal('86245')),
#  (825, 913, 'kevin_magnussen', Decimal('86231')),
#  (807, 927, 'hulkenberg', Decimal('86224')),
#  (4, 851, 'alonso', Decimal('86156')),
#  (4, 844, 'alonso', Decimal('86121')),
#  (3, 883, 'rosberg', Decimal('86018')),
#  (13, 973, 'massa', Decimal('85970')),
#  (831, 950, 'nasr', Decimal('85946')),
#  (3, 895, 'rosberg', Decimal('85940')),
#  (3, 962, 'rosberg', Decimal('85866')),
#  (16, 851, 'sutil', Decimal('85790')),
#  (153, 845, 'alguersuari', Decimal('85775')),
#  (13, 939, 'massa', Decimal('85702')),
#  (13, 940, 'massa', Decimal('85571')),
#  (836, 962, 'wehrlein', Decimal('85311')),
#  (829, 940, 'stevens', Decimal('85282')),
#  (815, 881, 'perez', Decimal('85181')),
#  (826, 982, 'kvyat', Decimal('85095')),
#  (811, 869, 'bruno_senna', Decimal('85077')),
#  (822, 917, 'bottas', Decimal('85041')),
#  (831, 962, 'nasr', Decimal('84891')),
#  (811, 874, 'bruno_senna', Decimal('84764')),
#  (3, 844, 'rosberg', Decimal('84757')),
#  (20, 881, 'vettel', Decimal('84713')),
#  (3, 851, 'rosberg', Decimal('84513')),
#  (18, 927, 'button', Decimal('84454')),
#  (4, 962, 'alonso', Decimal('84431')),
#  (808, 861, 'petrov', Decimal('84412')),
#  (17, 844, 'webber', Decimal('84401')),
#  (155, 879, 'kobayashi', Decimal('84343')),
#  (825, 962, 'kevin_magnussen', Decimal('84329')),
#  (826, 962, 'kvyat', Decimal('84090')),
#  (814, 844, 'resta', Decimal('83995')),
#  (833, 927, 'merhi', Decimal('83746')),
#  (814, 887, 'resta', Decimal('83504')),
#  (17, 881, 'webber', Decimal('83396')),
#  (154, 874, 'grosjean', Decimal('83265')),
#  (154, 890, 'grosjean', Decimal('83225')),
#  (5, 862, 'kovalainen', Decimal('83067')),
#  (37, 861, 'rosa', Decimal('83054')),
#  (807, 940, 'hulkenberg', Decimal('83001')),
#  (20, 929, 'vettel', Decimal('82879')),
#  (835, 962, 'jolyon_palmer', Decimal('82862')),
#  (8, 905, 'raikkonen', Decimal('82862')),
#  (837, 953, 'haryanto', Decimal('82789')),
#  (828, 956, 'ericsson', Decimal('82766')),
#  (836, 956, 'wehrlein', Decimal('82757')),
#  (822, 945, 'bottas', Decimal('82699')),
#  (820, 888, 'chilton', Decimal('82679')),
#  (820, 901, 'chilton', Decimal('82677')),
#  (1, 863, 'hamilton', Decimal('82659')),
#  (20, 962, 'vettel', Decimal('82657')),
#  (837, 956, 'haryanto', Decimal('82606')),
#  (3, 927, 'rosberg', Decimal('82599')),
#  (828, 901, 'ericsson', Decimal('82585')),
#  (8, 970, 'raikkonen', Decimal('82278')),
#  (813, 844, 'maldonado', Decimal('82188')),
#  (18, 956, 'button', Decimal('82165')),
#  (4, 942, 'alonso', Decimal('82023')),
#  (154, 949, 'grosjean', Decimal('81953')),
#  (4, 845, 'alonso', Decimal('81923')),
#  (20, 844, 'vettel', Decimal('81609')),
#  (821, 884, 'gutierrez', Decimal('81538')),
#  (832, 936, 'sainz', Decimal('81472')),
#  (826, 963, 'kvyat', Decimal('81469')),
#  (1, 845, 'hamilton', Decimal('81457')),
#  (826, 927, 'kvyat', Decimal('81393')),
#  (822, 956, 'bottas', Decimal('81362')),
#  (811, 859, 'bruno_senna', Decimal('81346')),
#  (1, 884, 'hamilton', Decimal('81307')),
#  (17, 845, 'webber', Decimal('81223')),
#  (817, 956, 'ricciardo', Decimal('81222')),
#  (1, 970, 'hamilton', Decimal('81020')),
#  (817, 970, 'ricciardo', Decimal('80938')),
#  (821, 916, 'gutierrez', Decimal('80931')),
#  (154, 952, 'grosjean', Decimal('80863')),
#  (20, 845, 'vettel', Decimal('80858')),
#  (807, 887, 'hulkenberg', Decimal('80803')),
#  (1, 956, 'hamilton', Decimal('80726')),
#  (17, 887, 'webber', Decimal('80702')),
#  (830, 970, 'max_verstappen', Decimal('80648')),
#  (821, 963, 'gutierrez', Decimal('80602')),
#  (67, 842, 'buemi', Decimal('80562')),
#  (13, 917, 'massa', Decimal('80222')),
#  (826, 951, 'kvyat', Decimal('80188')),
#  (837, 949, 'haryanto', Decimal('80019')),
#  (813, 930, 'maldonado', Decimal('80010')),
#  (813, 881, 'maldonado', Decimal('80001')),
#  (828, 970, 'ericsson', Decimal('79963')),
#  (830, 927, 'max_verstappen', Decimal('79939')),
#  (817, 860, 'ricciardo', Decimal('79924')),
#  (815, 949, 'perez', Decimal('79911')),
#  (815, 877, 'perez', Decimal('79775')),
#  (4, 956, 'alonso', Decimal('79761')),
#  (815, 895, 'perez', Decimal('79715')),
#  (814, 884, 'resta', Decimal('79710')),
#  (835, 956, 'jolyon_palmer', Decimal('79706')),
#  (815, 884, 'perez', Decimal('79687')),
#  (822, 927, 'bottas', Decimal('79588')),
#  (20, 849, 'vettel', Decimal('79513')),
#  (822, 888, 'bottas', Decimal('79491')),
#  (818, 870, 'vergne', Decimal('79465')),
#  (811, 860, 'bruno_senna', Decimal('79264')),
#  (817, 884, 'ricciardo', Decimal('79250')),
#  (3, 956, 'rosberg', Decimal('79104')),
#  (820, 902, 'chilton', Decimal('79072')),
#  (817, 951, 'ricciardo', Decimal('78968')),
#  (828, 944, 'ericsson', Decimal('78949')),
#  (821, 912, 'gutierrez', Decimal('78918')),
#  (154, 954, 'grosjean', Decimal('78849')),
#  (20, 864, 'vettel', Decimal('78847')),
#  (39, 848, 'karthikeyan', Decimal('78764')),
#  (821, 956, 'gutierrez', Decimal('78757')),
#  (13, 956, 'massa', Decimal('78731')),
#  (823, 887, 'garde', Decimal('78720')),
#  (16, 917, 'sutil', Decimal('78620')),
#  (1, 861, 'hamilton', Decimal('78570')),
#  (830, 931, 'max_verstappen', Decimal('78557')),
#  (815, 980, 'perez', Decimal('78457')),
#  (10, 843, 'glock', Decimal('78418')),
#  (813, 942, 'maldonado', Decimal('78351')),
#  (155, 861, 'kobayashi', Decimal('78039')),
#  (807, 896, 'hulkenberg', Decimal('77987')),
#  (3, 949, 'rosberg', Decimal('77921')),
#  (826, 901, 'kvyat', Decimal('77871')),
#  (5, 860, 'kovalainen', Decimal('77865')),
#  (815, 956, 'perez', Decimal('77809')),
#  (1, 846, 'hamilton', Decimal('77769')),
#  (817, 927, 'ricciardo', Decimal('77711')),
#  (153, 841, 'alguersuari', Decimal('77709')),
#  (20, 936, 'vettel', Decimal('77688')),
#  (13, 927, 'massa', Decimal('77590')),
#  (8, 861, 'raikkonen', Decimal('77570')),
#  (831, 929, 'nasr', Decimal('77567')),
#  (822, 953, 'bottas', Decimal('77515')),
#  (4, 896, 'alonso', Decimal('77461')),
#  (839, 965, 'ocon', Decimal('77413')),
#  (831, 949, 'nasr', Decimal('77397')),
#  (8, 950, 'raikkonen', Decimal('77262')),
#  (836, 949, 'wehrlein', Decimal('77202')),
#  (13, 884, 'massa', Decimal('77190')),
#  (836, 963, 'wehrlein', Decimal('77177')),
#  (18, 936, 'button', Decimal('77111')),
#  (838, 970, 'vandoorne', Decimal('77058')),
#  (16, 849, 'sutil', Decimal('77054')),
#  (17, 884, 'webber', Decimal('76920')),
#  (830, 950, 'max_verstappen', Decimal('76908')),
#  (815, 851, 'perez', Decimal('76903')),
#  (4, 884, 'alonso', Decimal('76851')),
#  (18, 942, 'button', Decimal('76837')),
#  (813, 910, 'maldonado', Decimal('76802')),
#  (39, 844, 'karthikeyan', Decimal('76789')),
#  (826, 902, 'kvyat', Decimal('76749')),
#  (817, 942, 'ricciardo', Decimal('76746')),
#  (8, 927, 'raikkonen', Decimal('76682')),
#  (812, 850, 'chandhok', Decimal('76668')),
#  (154, 911, 'grosjean', Decimal('76663')),
#  (8, 879, 'raikkonen', Decimal('76581')),
#  (830, 949, 'max_verstappen', Decimal('76533')),
#  (815, 917, 'perez', Decimal('76531')),
#  (154, 901, 'grosjean', Decimal('76377')),
#  (18, 846, 'button', Decimal('76371')),
#  (4, 847, 'alonso', Decimal('76370')),
#  (3, 911, 'rosberg', Decimal('76325')),
#  (807, 929, 'hulkenberg', Decimal('76310')),
#  (16, 842, 'sutil', Decimal('76290')),
#  (828, 931, 'ericsson', Decimal('76250')),
#  (839, 980, 'ocon', Decimal('76210')),
#  (37, 871, 'rosa', Decimal('76198')),
#  (4, 970, 'alonso', Decimal('76158')),
#  (10, 861, 'glock', Decimal('76146')),
#  (822, 902, 'bottas', Decimal('76088')),
#  (830, 963, 'max_verstappen', Decimal('76065')),
#  (817, 949, 'ricciardo', Decimal('76051')),
#  (10, 863, 'glock', Decimal('76004')),
#  (826, 970, 'kvyat', Decimal('75982')),
#  (836, 975, 'wehrlein', Decimal('75959')),
#  (822, 881, 'bottas', Decimal('75942')),
#  (154, 902, 'grosjean', Decimal('75917')),
#  (154, 869, 'grosjean', Decimal('75897')),
#  (835, 970, 'jolyon_palmer', Decimal('75876')),
#  (8, 980, 'raikkonen', Decimal('75869')),
#  (807, 963, 'hulkenberg', Decimal('75813')),
#  (13, 864, 'massa', Decimal('75733')),
#  (826, 916, 'kvyat', Decimal('75725')),
#  (3, 846, 'rosberg', Decimal('75615')),
#  (825, 949, 'kevin_magnussen', Decimal('75600')),
#  (24, 855, 'liuzzi', Decimal('75591')),
#  (20, 884, 'vettel', Decimal('75559')),
#  (154, 887, 'grosjean', Decimal('75387')),
#  (836, 950, 'wehrlein', Decimal('75347')),
#  (3, 887, 'rosberg', Decimal('75319')),
#  (8, 949, 'raikkonen', Decimal('75199')),
#  (8, 901, 'raikkonen', Decimal('75062')),
#  (154, 927, 'grosjean', Decimal('75012')),
#  (155, 903, 'kobayashi', Decimal('75007')),
#  (13, 902, 'massa', Decimal('74999')),
#  (822, 883, 'bottas', Decimal('74974')),
#  (832, 970, 'sainz', Decimal('74891')),
#  (8, 902, 'raikkonen', Decimal('74877')),
#  (1, 927, 'hamilton', Decimal('74868')),
#  (4, 902, 'alonso', Decimal('74839')),
#  (818, 895, 'vergne', Decimal('74779')),
#  (20, 942, 'vettel', Decimal('74753')),
#  (825, 902, 'kevin_magnussen', Decimal('74742')),
#  (20, 950, 'vettel', Decimal('74741')),
#  (815, 861, 'perez', Decimal('74734')),
#  (17, 847, 'webber', Decimal('74718')),
#  (832, 956, 'sainz', Decimal('74703')),
#  (3, 901, 'rosberg', Decimal('74664')),
#  (13, 842, 'massa', Decimal('74658')),
#  (4, 961, 'alonso', Decimal('74619')),
#  (838, 949, 'vandoorne', Decimal('74602')),
#  (808, 842, 'petrov', Decimal('74556')),
#  (822, 901, 'bottas', Decimal('74482')),
#  (18, 901, 'button', Decimal('74393')),
#  (1, 901, 'hamilton', Decimal('74384')),
#  (813, 849, 'maldonado', Decimal('74379')),
#  (4, 887, 'alonso', Decimal('74379')),
#  (20, 901, 'vettel', Decimal('74346')),
#  (153, 847, 'alguersuari', Decimal('74246')),
#  (5, 871, 'kovalainen', Decimal('74137')),
#  (826, 917, 'kvyat', Decimal('74112')),
#  (17, 861, 'webber', Decimal('74101')),
#  (1, 949, 'hamilton', Decimal('74066')),
#  (4, 849, 'alonso', Decimal('74014')),
#  (8, 963, 'raikkonen', Decimal('73805')),
#  (13, 901, 'massa', Decimal('73740')),
#  (815, 940, 'perez', Decimal('73611')),
#  (39, 845, 'karthikeyan', Decimal('73589')),
#  (821, 906, 'gutierrez', Decimal('73541')),
#  (839, 974, 'ocon', Decimal('73437')),
#  (837, 959, 'haryanto', Decimal('73422')),
#  (1, 911, 'hamilton', Decimal('73403')),
#  (4, 901, 'alonso', Decimal('73329')),
#  (826, 949, 'kvyat', Decimal('73304')),
#  (831, 945, 'nasr', Decimal('73299')),
#  (17, 849, 'webber', Decimal('73248')),
#  (8, 965, 'raikkonen', Decimal('73218')),
#  (808, 879, 'petrov', Decimal('73185')),
#  (4, 963, 'alonso', Decimal('73176')),
#  (30, 848, 'michael_schumacher', Decimal('73034')),
#  (155, 863, 'kobayashi', Decimal('73022')),
#  (832, 950, 'sainz', Decimal('72855')),
#  (5, 852, 'kovalainen', Decimal('72854')),
#  (813, 843, 'maldonado', Decimal('72842')),
#  (18, 895, 'button', Decimal('72830')),
#  (817, 944, 'ricciardo', Decimal('72691')),
#  (18, 849, 'button', Decimal('72649')),
#  (824, 910, 'jules_bianchi', Decimal('72622')),
#  (1, 849, 'hamilton', Decimal('72505')),
#  (13, 841, 'massa', Decimal('72437')),
#  (20, 965, 'vettel', Decimal('72401')),
#  (830, 944, 'max_verstappen', Decimal('72397')),
#  (818, 894, 'vergne', Decimal('72338')),
#  (825, 965, 'kevin_magnussen', Decimal('72311')),
#  (4, 937, 'alonso', Decimal('72267')),
#  (8, 916, 'raikkonen', Decimal('72229')),
#  (818, 901, 'vergne', Decimal('72227')),
#  (154, 944, 'grosjean', Decimal('72220')),
#  (818, 917, 'vergne', Decimal('72192')),
#  (837, 950, 'haryanto', Decimal('72187')),
#  (37, 863, 'rosa', Decimal('72181')),
#  (17, 841, 'webber', Decimal('72176')),
#  (4, 841, 'alonso', Decimal('72165')),
#  (814, 879, 'resta', Decimal('72089')),
#  (18, 896, 'button', Decimal('72045')),
#  (826, 977, 'kvyat', Decimal('72020')),
#  (24, 856, 'liuzzi', Decimal('72015')),
#  (18, 937, 'button', Decimal('71995')),
#  (833, 930, 'merhi', Decimal('71901')),
#  (1, 857, 'hamilton', Decimal('71895')),
#  (3, 963, 'rosberg', Decimal('71887')),
#  (823, 880, 'garde', Decimal('71855')),
#  (154, 917, 'grosjean', Decimal('71811')),
#  (18, 910, 'button', Decimal('71755')),
#  (13, 963, 'massa', Decimal('71731')),
#  (820, 899, 'chilton', Decimal('71731')),
#  (817, 934, 'ricciardo', Decimal('71704')),
#  (825, 973, 'kevin_magnussen', Decimal('71569')),
#  (820, 903, 'chilton', Decimal('71545')),
#  (13, 965, 'massa', Decimal('71460')),
#  (815, 864, 'perez', Decimal('71450')),
#  (3, 944, 'rosberg', Decimal('71406')),
#  (821, 957, 'gutierrez', Decimal('71392')),
#  (825, 917, 'kevin_magnussen', Decimal('71382')),
#  (828, 903, 'ericsson', Decimal('71376')),
#  (821, 917, 'gutierrez', Decimal('71346')),
#  (13, 849, 'massa', Decimal('71326')),
#  (820, 882, 'chilton', Decimal('71305')),
#  (16, 911, 'sutil', Decimal('71266')),
#  (13, 911, 'massa', Decimal('71252')),
#  (13, 944, 'massa', Decimal('71215')),
#  (815, 944, 'perez', Decimal('71195')),
#  (820, 904, 'chilton', Decimal('71155')),
#  (20, 944, 'vettel', Decimal('71136')),
#  (818, 899, 'vergne', Decimal('71089')),
#  (820, 885, 'chilton', Decimal('71088')),
#  (30, 861, 'michael_schumacher', Decimal('71088')),
#  (16, 883, 'sutil', Decimal('71040')),
#  (155, 871, 'kobayashi', Decimal('71023')),
#  (828, 980, 'ericsson', Decimal('71012')),
#  (818, 880, 'vergne', Decimal('70922')),
#  (18, 944, 'button', Decimal('70909')),
#  (821, 904, 'gutierrez', Decimal('70868')),
#  (822, 880, 'bottas', Decimal('70803')),
#  (807, 861, 'hulkenberg', Decimal('70763')),
#  (16, 843, 'sutil', Decimal('70755')),
#  (835, 973, 'jolyon_palmer', Decimal('70671')),
#  (817, 863, 'ricciardo', Decimal('70619')),
#  (822, 910, 'bottas', Decimal('70604')),
#  (815, 900, 'perez', Decimal('70564')),
#  (830, 937, 'max_verstappen', Decimal('70547')),
#  (829, 930, 'stevens', Decimal('70526')),
#  (8, 881, 'raikkonen', Decimal('70485')),
#  (1, 917, 'hamilton', Decimal('70449')),
#  (822, 949, 'bottas', Decimal('70423')),
#  (1, 944, 'hamilton', Decimal('70412')),
#  (828, 958, 'ericsson', Decimal('70379')),
#  (3, 917, 'rosberg', Decimal('70316')),
#  (807, 917, 'hulkenberg', Decimal('70288')),
#  (831, 943, 'nasr', Decimal('70256')),
#  (819, 879, 'pic', Decimal('70255')),
#  (835, 950, 'jolyon_palmer', Decimal('70178')),
#  (10, 855, 'glock', Decimal('70166')),
#  (16, 899, 'sutil', Decimal('70143')),
#  (3, 842, 'rosberg', Decimal('70070')),
#  (4, 861, 'alonso', Decimal('70051')),
#  (4, 944, 'alonso', Decimal('70009')),
#  (808, 863, 'petrov', Decimal('69999')),
#  (18, 930, 'button', Decimal('69982')),
#  (832, 943, 'sainz', Decimal('69972')),
#  (821, 950, 'gutierrez', Decimal('69911')),
#  (826, 940, 'kvyat', Decimal('69880')),
#  (817, 855, 'ricciardo', Decimal('69805')),
#  (815, 863, 'perez', Decimal('69760')),
#  (20, 917, 'vettel', Decimal('69749')),
#  (808, 864, 'petrov', Decimal('69745')),
#  (2, 842, 'heidfeld', Decimal('69723')),
#  (828, 943, 'ericsson', Decimal('69709')),
#  (813, 917, 'maldonado', Decimal('69708')),
#  (18, 950, 'button', Decimal('69611')),
#  (831, 959, 'nasr', Decimal('69564')),
#  (816, 855, 'ambrosio', Decimal('69540')),
#  (835, 968, 'jolyon_palmer', Decimal('69514')),
#  (4, 917, 'alonso', Decimal('69489')),
#  (17, 895, 'webber', Decimal('69485')),
#  (825, 980, 'kevin_magnussen', Decimal('69473')),
#  (24, 848, 'liuzzi', Decimal('69460')),
#  (18, 852, 'button', Decimal('69442')),
#  (824, 880, 'jules_bianchi', Decimal('69427')),
#  (826, 950, 'kvyat', Decimal('69375')),
#  (20, 847, 'vettel', Decimal('69356')),
#  (815, 928, 'perez', Decimal('69311')),
#  (817, 950, 'ricciardo', Decimal('69279')),
#  (1, 930, 'hamilton', Decimal('69278')),
#  (814, 842, 'resta', Decimal('69169')),
#  (825, 950, 'kevin_magnussen', Decimal('69092')),
#  (830, 938, 'max_verstappen', Decimal('69074')),
#  (18, 917, 'button', Decimal('69021')),
#  (814, 861, 'resta', Decimal('69019')),
#  (818, 862, 'vergne', Decimal('68989')),
#  (821, 903, 'gutierrez', Decimal('68974')),
#  (4, 973, 'alonso', Decimal('68967')),
#  (154, 863, 'grosjean', Decimal('68905')),
#  (828, 933, 'ericsson', Decimal('68892')),
#  (828, 952, 'ericsson', Decimal('68859')),
#  (17, 894, 'webber', Decimal('68795')),
#  (818, 890, 'vergne', Decimal('68783')),
#  (813, 890, 'maldonado', Decimal('68779')),
#  (819, 883, 'pic', Decimal('68751')),
#  (4, 863, 'alonso', Decimal('68750')),
#  (20, 911, 'vettel', Decimal('68721')),
#  (3, 910, 'rosberg', Decimal('68692')),
#  (155, 856, 'kobayashi', Decimal('68673')),
#  (67, 843, 'buemi', Decimal('68660')),
#  (826, 904, 'kvyat', Decimal('68528')),
#  (811, 863, 'bruno_senna', Decimal('68511')),
#  (814, 890, 'resta', Decimal('68504')),
#  (821, 896, 'gutierrez', Decimal('68498')),
#  (823, 890, 'garde', Decimal('68415')),
#  (818, 863, 'vergne', Decimal('68357')),
#  (828, 926, 'ericsson', Decimal('68288')),
#  (826, 952, 'kvyat', Decimal('68280')),
#  (829, 939, 'stevens', Decimal('68245')),
#  (39, 846, 'karthikeyan', Decimal('68242')),
#  (817, 910, 'ricciardo', Decimal('68219')),
#  (820, 884, 'chilton', Decimal('68216')),
#  (823, 899, 'garde', Decimal('68178')),
#  (15, 844, 'trulli', Decimal('68147')),
#  (825, 952, 'kevin_magnussen', Decimal('68130')),
#  (822, 950, 'bottas', Decimal('68059')),
#  (817, 851, 'ricciardo', Decimal('68058')),
#  (815, 950, 'perez', Decimal('68051')),
#  (818, 918, 'vergne', Decimal('68028')),
#  (811, 853, 'bruno_senna', Decimal('67952')),
#  (820, 890, 'chilton', Decimal('67881')),
#  (816, 845, 'ambrosio', Decimal('67866')),
#  (155, 851, 'kobayashi', Decimal('67835')),
#  (808, 845, 'petrov', Decimal('67827')),
#  (828, 909, 'ericsson', Decimal('67808')),
#  (154, 883, 'grosjean', Decimal('67769')),
#  (807, 930, 'hulkenberg', Decimal('67738')),
#  (155, 844, 'kobayashi', Decimal('67731')),
#  (18, 862, 'button', Decimal('67655')),
#  (30, 859, 'michael_schumacher', Decimal('67636')),
#  (153, 851, 'alguersuari', Decimal('67631')),
#  (5, 844, 'kovalainen', Decimal('67601')),
#  (13, 904, 'massa', Decimal('67575')),
#  (830, 941, 'max_verstappen', Decimal('67575')),
#  (17, 880, 'webber', Decimal('67472')),
#  (813, 883, 'maldonado', Decimal('67459')),
#  (13, 863, 'massa', Decimal('67458')),
#  (807, 863, 'hulkenberg', Decimal('67419')),
#  (818, 909, 'vergne', Decimal('67416')),
#  (824, 890, 'jules_bianchi', Decimal('67410')),
#  (18, 880, 'button', Decimal('67391')),
#  (815, 880, 'perez', Decimal('67386')),
#  (8, 863, 'raikkonen', Decimal('67371')),
#  (18, 842, 'button', Decimal('67354')),
#  (4, 879, 'alonso', Decimal('67334')),
#  (22, 844, 'barrichello', Decimal('67272')),
#  (13, 910, 'massa', Decimal('67240')),
#  (20, 842, 'vettel', Decimal('67225')),
#  (817, 883, 'ricciardo', Decimal('67180')),
#  (830, 945, 'max_verstappen', Decimal('67121')),
#  (15, 845, 'trulli', Decimal('67088')),
#  (819, 888, 'pic', Decimal('67073')),
#  (30, 842, 'michael_schumacher', Decimal('67064')),
#  (13, 930, 'massa', Decimal('67025')),
#  (3, 863, 'rosberg', Decimal('67019')),
#  (5, 848, 'kovalainen', Decimal('66999')),
#  (16, 918, 'sutil', Decimal('66995')),
#  (3, 959, 'rosberg', Decimal('66993')),
#  (13, 860, 'massa', Decimal('66944')),
#  (154, 880, 'grosjean', Decimal('66906')),
#  (822, 942, 'bottas', Decimal('66872')),
#  (807, 883, 'hulkenberg', Decimal('66870')),
#  (817, 881, 'ricciardo', Decimal('66812')),
#  (814, 877, 'resta', Decimal('66764')),
#  (22, 855, 'barrichello', Decimal('66756')),
#  (13, 879, 'massa', Decimal('66703')),
#  (819, 895, 'pic', Decimal('66696')),
#  (814, 857, 'resta', Decimal('66659')),
#  (13, 848, 'massa', Decimal('66659')),
#  (813, 885, 'maldonado', Decimal('66653')),
#  (17, 863, 'webber', Decimal('66590')),
#  (817, 895, 'ricciardo', Decimal('66587')),
#  (815, 845, 'perez', Decimal('66564')),
#  (830, 929, 'max_verstappen', Decimal('66563')),
#  (824, 882, 'jules_bianchi', Decimal('66556')),
#  (20, 863, 'vettel', Decimal('66534')),
#  (155, 845, 'kobayashi', Decimal('66499')),
#  (3, 890, 'rosberg', Decimal('66497')),
#  (67, 845, 'buemi', Decimal('66382')),
#  (13, 890, 'massa', Decimal('66377')),
#  (5, 859, 'kovalainen', Decimal('66345')),
#  (154, 881, 'grosjean', Decimal('66302')),
#  (30, 863, 'michael_schumacher', Decimal('66276')),
#  (17, 890, 'webber', Decimal('66133')),
#  (20, 880, 'vettel', Decimal('66107')),
#  (20, 905, 'vettel', Decimal('66065')),
#  (155, 868, 'kobayashi', Decimal('66053')),
#  (808, 859, 'petrov', Decimal('66052')),
#  (823, 894, 'garde', Decimal('66048')),
#  (16, 902, 'sutil', Decimal('66040')),
#  (15, 855, 'trulli', Decimal('66025')),
#  (838, 972, 'vandoorne', Decimal('66004')),
#  (1, 880, 'hamilton', Decimal('65948')),
#  (67, 844, 'buemi', Decimal('65929')),
#  (2, 848, 'heidfeld', Decimal('65871')),
#  (20, 952, 'vettel', Decimal('65863')),
#  (3, 894, 'rosberg', Decimal('65844')),
#  (13, 952, 'massa', Decimal('65783')),
#  (18, 843, 'button', Decimal('65774')),
#  (22, 859, 'barrichello', Decimal('65765')),
#  (835, 959, 'jolyon_palmer', Decimal('65711')),
#  (20, 855, 'vettel', Decimal('65675')),
#  (17, 843, 'webber', Decimal('65665')),
#  (4, 904, 'alonso', Decimal('65648')),
#  (817, 882, 'ricciardo', Decimal('65611')),
#  (13, 852, 'massa', Decimal('65608')),
#  (4, 890, 'alonso', Decimal('65601')),
#  (10, 845, 'glock', Decimal('65546')),
#  (811, 852, 'bruno_senna', Decimal('65519')),
#  (3, 848, 'rosberg', Decimal('65497')),
#  (814, 855, 'resta', Decimal('65481')),
#  (5, 855, 'kovalainen', Decimal('65463')),
#  (820, 909, 'chilton', Decimal('65435')),
#  (1, 890, 'hamilton', Decimal('65430')),
#  (18, 844, 'button', Decimal('65424')),
#  (17, 879, 'webber', Decimal('65365')),
#  (833, 934, 'merhi', Decimal('65358')),
#  (820, 891, 'chilton', Decimal('65356')),
#  (822, 882, 'bottas', Decimal('65321')),
#  (821, 951, 'gutierrez', Decimal('65206')),
#  (1, 855, 'hamilton', Decimal('65204')),
#  (20, 904, 'vettel', Decimal('65181')),
#  (5, 864, 'kovalainen', Decimal('65131')),
#  (1, 883, 'hamilton', Decimal('65116')),
#  (17, 864, 'webber', Decimal('65112')),
#  (4, 880, 'alonso', Decimal('65102')),
#  (18, 866, 'button', Decimal('64956')),
#  (153, 858, 'alguersuari', Decimal('64937')),
#  (3, 882, 'rosberg', Decimal('64920')),
#  (5, 845, 'kovalainen', Decimal('64894')),
#  (20, 890, 'vettel', Decimal('64872')),
#  (20, 883, 'vettel', Decimal('64856')),
#  (13, 845, 'massa', Decimal('64854')),
#  (13, 880, 'massa', Decimal('64774')),
#  (819, 882, 'pic', Decimal('64742')),
#  (17, 858, 'webber', Decimal('64707')),
#  (16, 855, 'sutil', Decimal('64687')),
#  (17, 855, 'webber', Decimal('64644')),
#  (18, 859, 'button', Decimal('64626')),
#  (813, 848, 'maldonado', Decimal('64596')),
#  (815, 856, 'perez', Decimal('64581')),
#  (39, 861, 'karthikeyan', Decimal('64576')),
#  (154, 885, 'grosjean', Decimal('64545')),
#  (1, 899, 'hamilton', Decimal('64463')),
#  (825, 909, 'kevin_magnussen', Decimal('64421')),
#  (13, 857, 'massa', Decimal('64386')),
#  (808, 848, 'petrov', Decimal('64377')),
#  (155, 862, 'kobayashi', Decimal('64358')),
#  (16, 845, 'sutil', Decimal('64270')),
#  (67, 851, 'buemi', Decimal('64169')),
#  (815, 854, 'perez', Decimal('64154')),
#  (822, 937, 'bottas', Decimal('64151')),
#  (16, 854, 'sutil', Decimal('64136')),
#  (30, 855, 'michael_schumacher', Decimal('64116')),
#  (821, 909, 'gutierrez', Decimal('64086')),
#  (39, 867, 'karthikeyan', Decimal('64080')),
#  (2, 845, 'heidfeld', Decimal('64071')),
#  (815, 852, 'perez', Decimal('64064')),
#  (830, 981, 'max_verstappen', Decimal('64061')),
#  (17, 883, 'webber', Decimal('64050')),
#  (17, 846, 'webber', Decimal('64004')),
#  (814, 851, 'resta', Decimal('63998')),
#  (155, 864, 'kobayashi', Decimal('63952')),
#  (815, 883, 'perez', Decimal('63951')),
#  (30, 843, 'michael_schumacher', Decimal('63886')),
#  (819, 874, 'pic', Decimal('63848')),
#  (154, 873, 'grosjean', Decimal('63833')),
#  (10, 851, 'glock', Decimal('63764')),
#  (16, 844, 'sutil', Decimal('63739')),
#  (22, 848, 'barrichello', Decimal('63711')),
#  (20, 859, 'vettel', Decimal('63673')),
#  (813, 864, 'maldonado', Decimal('63667')),
#  (13, 895, 'massa', Decimal('63639')),
#  (13, 855, 'massa', Decimal('63627')),
#  (20, 978, 'vettel', Decimal('63567')),
#  (3, 843, 'rosberg', Decimal('63496')),
#  (818, 864, 'vergne', Decimal('63493')),
#  (813, 855, 'maldonado', Decimal('63426')),
#  (823, 888, 'garde', Decimal('63419')),
#  (3, 886, 'rosberg', Decimal('63416')),
#  (832, 949, 'sainz', Decimal('63379')),
#  (816, 854, 'ambrosio', Decimal('63355')),
#  (813, 882, 'maldonado', Decimal('63293')),
#  (813, 928, 'maldonado', Decimal('63281')),
#  (834, 939, 'rossi', Decimal('63216')),
#  (5, 870, 'kovalainen', Decimal('63202')),
#  (815, 951, 'perez', Decimal('63200')),
#  (4, 855, 'alonso', Decimal('63197')),
#  (16, 859, 'sutil', Decimal('63135')),
#  (807, 882, 'hulkenberg', Decimal('63122')),
#  (20, 852, 'vettel', Decimal('63095')),
#  (832, 940, 'sainz', Decimal('63046')),
#  (10, 873, 'glock', Decimal('62992')),
#  (821, 891, 'gutierrez', Decimal('62906')),
#  (18, 851, 'button', Decimal('62897')),
#  (828, 972, 'ericsson', Decimal('62890')),
#  (18, 841, 'button', Decimal('62851')),
#  (829, 941, 'stevens', Decimal('62821')),
#  (819, 884, 'pic', Decimal('62806')),
#  (18, 855, 'button', Decimal('62805')),
#  (67, 848, 'buemi', Decimal('62776')),
#  (826, 959, 'kvyat', Decimal('62734')),
#  (823, 882, 'garde', Decimal('62715')),
#  (10, 864, 'glock', Decimal('62653')),
#  (17, 859, 'webber', Decimal('62526')),
#  (154, 957, 'grosjean', Decimal('62514')),
#  (8, 893, 'raikkonen', Decimal('62482')),
#  (154, 864, 'grosjean', Decimal('62473')),
#  (814, 848, 'resta', Decimal('62454')),
#  (807, 934, 'hulkenberg', Decimal('62449')),
#  (13, 850, 'massa', Decimal('62432')),
#  (13, 899, 'massa', Decimal('62364')),
#  (826, 934, 'kvyat', Decimal('62326')),
#  (4, 859, 'alonso', Decimal('62189')),
#  (808, 870, 'petrov', Decimal('62177')),
#  (1, 859, 'hamilton', Decimal('62176')),
#  (4, 848, 'alonso', Decimal('62164')),
#  (807, 888, 'hulkenberg', Decimal('62147')),
#  (24, 843, 'liuzzi', Decimal('62126')),
#  (826, 939, 'kvyat', Decimal('62083')),
#  (822, 887, 'bottas', Decimal('62082')),
#  (10, 865, 'glock', Decimal('62070')),
#  (836, 972, 'wehrlein', Decimal('62065')),
#  (17, 850, 'webber', Decimal('62063')),
#  (830, 939, 'max_verstappen', Decimal('62051')),
#  (3, 855, 'rosberg', Decimal('62049')),
#  (832, 959, 'sainz', Decimal('62045')),
#  (16, 848, 'sutil', Decimal('61998')),
#  (1, 843, 'hamilton', Decimal('61978')),
#  (8, 882, 'raikkonen', Decimal('61976')),
#  (818, 882, 'vergne', Decimal('61928')),
#  (16, 888, 'sutil', Decimal('61913')),
#  (826, 915, 'kvyat', Decimal('61905')),
#  (1, 850, 'hamilton', Decimal('61881')),
#  (13, 869, 'massa', Decimal('61866')),
#  (18, 848, 'button', Decimal('61801')),
#  (815, 894, 'perez', Decimal('61794')),
#  (828, 915, 'ericsson', Decimal('61780')),
#  (20, 848, 'vettel', Decimal('61778')),
#  (1, 862, 'hamilton', Decimal('61771')),
#  (30, 852, 'michael_schumacher', Decimal('61698')),
#  (5, 898, 'kovalainen', Decimal('61656')),
#  (822, 884, 'bottas', Decimal('61612')),
#  (807, 864, 'hulkenberg', Decimal('61594')),
#  (1, 848, 'hamilton', Decimal('61587')),
#  (3, 888, 'rosberg', Decimal('61581')),
#  (815, 909, 'perez', Decimal('61577')),
#  (8, 956, 'raikkonen', Decimal('61577')),
#  (815, 962, 'perez', Decimal('61563')),
#  (814, 864, 'resta', Decimal('61534')),
#  (819, 873, 'pic', Decimal('61481')),
#  (18, 958, 'button', Decimal('61433')),
#  (830, 957, 'max_verstappen', Decimal('61424')),
#  (807, 890, 'hulkenberg', Decimal('61421')),
#  (831, 956, 'nasr', Decimal('61375')),
#  (807, 897, 'hulkenberg', Decimal('61373')),
#  (3, 850, 'rosberg', Decimal('61370')),
#  (1, 971, 'hamilton', Decimal('61369')),
#  (17, 862, 'webber', Decimal('61322')),
#  (13, 934, 'massa', Decimal('61317')),
#  (18, 864, 'button', Decimal('61282')),
#  (817, 864, 'ricciardo', Decimal('61274')),
#  (4, 882, 'alonso', Decimal('61252')),
#  (30, 873, 'michael_schumacher', Decimal('61217')),
#  (17, 848, 'webber', Decimal('61151')),
#  (8, 864, 'raikkonen', Decimal('61151')),
#  (831, 957, 'nasr', Decimal('61124')),
#  (154, 956, 'grosjean', Decimal('61076')),
#  (821, 893, 'gutierrez', Decimal('61070')),
#  (8, 959, 'raikkonen', Decimal('61060')),
#  (814, 873, 'resta', Decimal('61055')),
#  (815, 927, 'perez', Decimal('61044')),
#  (30, 845, 'michael_schumacher', Decimal('61022')),
#  (22, 854, 'barrichello', Decimal('61000')),
#  (30, 850, 'michael_schumacher', Decimal('60997')),
#  (20, 851, 'vettel', Decimal('60965')),
#  (828, 951, 'ericsson', Decimal('60962')),
#  (18, 845, 'button', Decimal('60885')),
#  (815, 934, 'perez', Decimal('60858')),
#  (821, 888, 'gutierrez', Decimal('60845')),
#  (817, 873, 'ricciardo', Decimal('60781')),
#  (20, 850, 'vettel', Decimal('60778')),
#  (814, 845, 'resta', Decimal('60769')),
#  ...]

# %% [markdown]
# ## 5) Time to put everything together. Use the query for 4 as a join subquery in query 3 (see slides on "a query within a query") to find the total amount of pitstop time, for each result in query 3

# %%
# %%sql SELECT drivers.driverref, constructors.name, count(driverref), SUM(pitstop_total_ms) AS pitstop_total_ms
# FROM drivers
# JOIN results on results.driverid = drivers.driverid
# JOIN constructors USING (constructorid)
# JOIN status USING (statusid)
# INNER JOIN (SELECT * FROM ms_pitstops) as pitstop_time USING (driverref)
# WHERE status='Finished'
# GROUP BY drivers.driverref, constructors.name
# ORDER BY count(driverref) DESC;
# Out:
# 118 rows affected.
# [('massa', 'Ferrari', 14112, Decimal('1708078064')),
#  ('vettel', 'Red Bull', 12125, Decimal('1398666086')),
#  ('rosberg', 'Mercedes', 12099, Decimal('1350554908')),
#  ('hamilton', 'Mercedes', 10795, Decimal('1233697310')),
#  ('hamilton', 'McLaren', 10668, Decimal('1219183224')),
#  ('alonso', 'Ferrari', 10614, Decimal('1150974156')),
#  ('alonso', 'Renault', 9760, Decimal('1058367040')),
#  ('button', 'McLaren', 9657, Decimal('1026662031')),
#  ('raikkonen', 'Ferrari', 9384, Decimal('920149684')),
#  ('ricciardo', 'Red Bull', 6776, Decimal('863136792')),
#  ('vettel', 'Ferrari', 6000, Decimal('692123424')),
#  ('webber', 'Red Bull', 5600, Decimal('334503000')),
#  ('michael_schumacher', 'Ferrari', 5358, Decimal('286053468')),
#  ('raikkonen', 'McLaren', 5304, Decimal('520084604')),
#  ('massa', 'Williams', 5166, Decimal('625278577')),
#  ('hulkenberg', 'Force India', 5047, Decimal('654072825')),
#  ('bottas', 'Williams', 4732, Decimal('654717856')),
#  ('perez', 'Force India', 4712, Decimal('551153596')),
#  ('rosberg', 'Williams', 3996, Decimal('446054832')),
#  ('alonso', 'McLaren', 3538, Decimal('383658052')),
#  ('raikkonen', 'Lotus F1', 3366, Decimal('330053691')),
#  ('grosjean', 'Lotus F1', 3201, Decimal('320267343')),
#  ('button', 'BAR', 2997, Decimal('318619251')),
#  ('ricciardo', 'Toro Rosso', 2662, Decimal('339089454')),
#  ('button', 'Honda', 2109, Decimal('224213547')),
#  ('resta', 'Force India', 1972, Decimal('103995834')),
#  ('perez', 'Sauber', 1860, Decimal('217560630')),
#  ('button', 'Brawn', 1776, Decimal('188811408')),
#  ('perez', 'McLaren', 1736, Decimal('203056588')),
#  ('maldonado', 'Williams', 1701, Decimal('123837546')),
#  ('sutil', 'Force India', 1683, Decimal('138317949')),
#  ('michael_schumacher', 'Benetton', 1672, Decimal('89264912')),
#  ('massa', 'Sauber', 1638, Decimal('198259061')),
#  ('vergne', 'Toro Rosso', 1540, Decimal('116165588')),
#  ('vettel', 'Toro Rosso', 1500, Decimal('173030856')),
#  ('kobayashi', 'Sauber', 1400, Decimal('104355160')),
#  ('hulkenberg', 'Sauber', 1339, Decimal('173529525')),
#  ('barrichello', 'Ferrari', 1314, Decimal('89852123')),
#  ('michael_schumacher', 'Mercedes', 1292, Decimal('68977432')),
#  ('bottas', 'Mercedes', 1274, Decimal('176270192')),
#  ('grosjean', 'Haas F1 Team', 1067, Decimal('106755781')),
#  ('max_verstappen', 'Red Bull', 1056, Decimal('180424728')),
#  ('kovalainen', 'McLaren', 920, Decimal('56033934')),
#  ('sainz', 'Toro Rosso', 900, Decimal('150423732')),
#  ('maldonado', 'Lotus F1', 891, Decimal('64867286')),
#  ('glock', 'Toyota', 792, Decimal('39177512')),
#  ('kvyat', 'Toro Rosso', 737, Decimal('103288801')),
#  ('webber', 'Williams', 728, Decimal('43485390')),
#  ('hulkenberg', 'Williams', 721, Decimal('93438975')),
#  ('trulli', 'Toyota', 714, Decimal('40069974')),
#  ('button', 'Renault', 666, Decimal('70804278')),
#  ('kevin_magnussen', 'McLaren', 624, Decimal('116668440')),
#  ('gutierrez', 'Sauber', 616, Decimal('96698316')),
#  ('kvyat', 'Red Bull', 603, Decimal('84509019')),
#  ('max_verstappen', 'Toro Rosso', 528, Decimal('90212364')),
#  ('petrov', 'Renault', 518, Decimal('28859488')),
#  ('hulkenberg', 'Renault', 515, Decimal('66742125')),
#  ('raikkonen', 'Sauber', 510, Decimal('50008135')),
#  ('heidfeld', 'BMW Sauber', 470, Decimal('26946651')),
#  ('ericsson', 'Sauber', 448, Decimal('50518993')),
#  ('webber', 'Jaguar', 448, Decimal('26760240')),
#  ('button', 'Williams', 444, Decimal('47202852')),
#  ('kovalainen', 'Renault', 440, Decimal('26798838')),
#  ('trulli', 'Renault', 357, Decimal('20034987')),
#  ('nasr', 'Sauber', 351, Decimal('76621797')),
#  ('bruno_senna', 'Williams', 338, Decimal('18983276')),
#  ('barrichello', 'Honda', 324, Decimal('22155318')),
#  ('buemi', 'Toro Rosso', 306, Decimal('17729946')),
#  ('barrichello', 'Brawn', 288, Decimal('19693616')),
#  ('barrichello', 'Williams', 252, Decimal('17231914')),
#  ('barrichello', 'Jordan', 252, Decimal('17231914')),
#  ('alguersuari', 'Toro Rosso', 252, Decimal('14365134')),
#  ('button', 'Benetton', 222, Decimal('23601426')),
#  ('ocon', 'Force India', 192, Decimal('57093520')),
#  ('liuzzi', 'Force India', 192, Decimal('13482216')),
#  ('barrichello', 'Stewart', 180, Decimal('12308510')),
#  ('jolyon_palmer', 'Renault', 174, Decimal('21507378')),
#  ('kevin_magnussen', 'Renault', 156, Decimal('29167110')),
#  ('kevin_magnussen', 'Haas F1 Team', 156, Decimal('29167110')),
#  ('trulli', 'Jordan', 153, Decimal('8586423')),
#  ('chilton', 'Marussia', 132, Decimal('12848932')),
#  ('vettel', 'BMW Sauber', 125, Decimal('14419238')),
#  ('kovalainen', 'Caterham', 120, Decimal('7308774')),
#  ('trulli', 'Prost', 119, Decimal('6678329')),
#  ('gutierrez', 'Haas F1 Team', 112, Decimal('17581512')),
#  ('rosa', 'McLaren', 102, Decimal('5605026')),
#  ('sutil', 'Sauber', 102, Decimal('8382906')),
#  ('heidfeld', 'Sauber', 100, Decimal('5733330')),
#  ('kobayashi', 'Toyota', 100, Decimal('7453940')),
#  ('grosjean', 'Renault', 97, Decimal('9705071')),
#  ('jules_bianchi', 'Marussia', 96, Decimal('8820603')),
#  ('rosa', 'Sauber', 85, Decimal('4670855')),
#  ('petrov', 'Caterham', 74, Decimal('4122784')),
#  ('pic', 'Caterham', 74, Decimal('3860832')),
#  ('pic', 'Marussia', 74, Decimal('3860832')),
#  ('glock', 'Marussia', 72, Decimal('3561592')),
#  ('ericsson', 'Caterham', 64, Decimal('7216999')),
#  ('stroll', 'Williams', 56, Decimal('7560068')),
#  ('bruno_senna', 'Renault', 52, Decimal('2920504')),
#  ('sutil', 'Spyker', 51, Decimal('4191453')),
#  ('garde', 'Caterham', 51, Decimal('3592830')),
#  ('kobayashi', 'Caterham', 50, Decimal('3726970')),
#  ('heidfeld', 'Williams', 50, Decimal('2866665')),
#  ('liuzzi', 'Toro Rosso', 48, Decimal('3370554')),
#  ('vandoorne', 'McLaren', 42, Decimal('6065013')),
#  ('heidfeld', 'Renault', 40, Decimal('2293332')),
#  ('kovalainen', 'Lotus', 40, Decimal('2436258')),
#  ('kovalainen', 'Lotus F1', 40, Decimal('2436258')),
#  ('rosa', 'Arrows', 34, Decimal('1868342')),
#  ('liuzzi', 'Red Bull', 32, Decimal('2247036')),
#  ('wehrlein', 'Manor Marussia', 31, Decimal('7670219')),
#  ('wehrlein', 'Sauber', 31, Decimal('7670219')),
#  ('ocon', 'Manor Marussia', 24, Decimal('7136690')),
#  ('ambrosio', 'Lotus F1', 18, Decimal('1043218')),
#  ('trulli', 'Lotus', 17, Decimal('954047')),
#  ('rosa', 'HRT', 17, Decimal('934171')),
#  ('rosa', 'Jaguar', 17, Decimal('934171')),
#  ('rossi', 'Manor Marussia', 5, Decimal('311537'))]

# %% [markdown]
# For some reason, the count differs from the query in task 3. I haven't been able to figure out why this is.

# %% [markdown]
# ## As a last thing we want to find the driver with the least pistop time. However we want to control for the amount of races (see explanation below), so we need to include one last column: the average pitstop time per race. Your table should be sorted based on the ascending values of that average pitstop time.

# %%
# %%sql SELECT drivers.driverref, constructors.name, SUM(pitstop_total_ms) AS pitstop_total_ms, AVG(pitstop_total_ms) AS pitstop_avg_ms
# FROM drivers
# JOIN results on results.driverid = drivers.driverid
# JOIN constructors USING (constructorid)
# JOIN status USING (statusid)
# JOIN races USING (raceid)
# INNER JOIN (SELECT * FROM ms_pitstops) as pitstop_time USING (driverref)
# WHERE status='Finished'
# GROUP BY drivers.driverref, constructors.name
# ORDER BY AVG(pitstop_total_ms) ASC;
# Out:
# 118 rows affected.
# [('glock', 'Toyota', Decimal('39177512'), Decimal('49466.555555555556')),
#  ('glock', 'Marussia', Decimal('3561592'), Decimal('49466.555555555556')),
#  ('pic', 'Caterham', Decimal('3860832'), Decimal('52173.405405405405')),
#  ('pic', 'Marussia', Decimal('3860832'), Decimal('52173.405405405405')),
#  ('resta', 'Force India', Decimal('103995834'), Decimal('52736.224137931034')),
#  ('michael_schumacher', 'Ferrari', Decimal('286053468'), Decimal('53388.105263157895')),
#  ('michael_schumacher', 'Mercedes', Decimal('68977432'), Decimal('53388.105263157895')),
#  ('michael_schumacher', 'Benetton', Decimal('89264912'), Decimal('53388.105263157895')),
#  ('rosa', 'HRT', Decimal('934171'), Decimal('54951.235294117647')),
#  ('rosa', 'McLaren', Decimal('5605026'), Decimal('54951.235294117647')),
#  ('rosa', 'Sauber', Decimal('4670855'), Decimal('54951.235294117647')),
#  ('rosa', 'Arrows', Decimal('1868342'), Decimal('54951.235294117647')),
#  ('rosa', 'Jaguar', Decimal('934171'), Decimal('54951.235294117647')),
#  ('petrov', 'Renault', Decimal('28859488'), Decimal('55713.297297297297')),
#  ('petrov', 'Caterham', Decimal('4122784'), Decimal('55713.297297297297')),
#  ('trulli', 'Prost', Decimal('6678329'), Decimal('56120.411764705882')),
#  ('trulli', 'Renault', Decimal('20034987'), Decimal('56120.411764705882')),
#  ('trulli', 'Lotus', Decimal('954047'), Decimal('56120.411764705882')),
#  ('trulli', 'Jordan', Decimal('8586423'), Decimal('56120.411764705882')),
#  ('trulli', 'Toyota', Decimal('40069974'), Decimal('56120.411764705882')),
#  ('bruno_senna', 'Renault', Decimal('2920504'), Decimal('56163.538461538462')),
#  ('bruno_senna', 'Williams', Decimal('18983276'), Decimal('56163.538461538462')),
#  ('alguersuari', 'Toro Rosso', Decimal('14365134'), Decimal('57004.500000000000')),
#  ('heidfeld', 'Renault', Decimal('2293332'), Decimal('57333.300000000000')),
#  ('heidfeld', 'Williams', Decimal('2866665'), Decimal('57333.300000000000')),
#  ('heidfeld', 'Sauber', Decimal('5733330'), Decimal('57333.300000000000')),
#  ('heidfeld', 'BMW Sauber', Decimal('26946651'), Decimal('57333.300000000000')),
#  ('buemi', 'Toro Rosso', Decimal('17729946'), Decimal('57941.000000000000')),
#  ('ambrosio', 'Lotus F1', Decimal('1043218'), Decimal('57956.555555555556')),
#  ('webber', 'Williams', Decimal('43485390'), Decimal('59732.678571428571')),
#  ('webber', 'Jaguar', Decimal('26760240'), Decimal('59732.678571428571')),
#  ('webber', 'Red Bull', Decimal('334503000'), Decimal('59732.678571428571')),
#  ('kovalainen', 'Caterham', Decimal('7308774'), Decimal('60906.450000000000')),
#  ('kovalainen', 'Lotus', Decimal('2436258'), Decimal('60906.450000000000')),
#  ('kovalainen', 'McLaren', Decimal('56033934'), Decimal('60906.450000000000')),
#  ('kovalainen', 'Renault', Decimal('26798838'), Decimal('60906.450000000000')),
#  ('kovalainen', 'Lotus F1', Decimal('2436258'), Decimal('60906.450000000000')),
#  ('rossi', 'Manor Marussia', Decimal('311537'), Decimal('62307.400000000000')),
#  ('barrichello', 'Stewart', Decimal('12308510'), Decimal('68380.611111111111')),
#  ('barrichello', 'Brawn', Decimal('19693616'), Decimal('68380.611111111111')),
#  ('barrichello', 'Honda', Decimal('22155318'), Decimal('68380.611111111111')),
#  ('barrichello', 'Jordan', Decimal('17231914'), Decimal('68380.611111111111')),
#  ('barrichello', 'Ferrari', Decimal('89852123'), Decimal('68380.611111111111')),
#  ('barrichello', 'Williams', Decimal('17231914'), Decimal('68380.611111111111')),
#  ('liuzzi', 'Toro Rosso', Decimal('3370554'), Decimal('70219.875000000000')),
#  ('liuzzi', 'Force India', Decimal('13482216'), Decimal('70219.875000000000')),
#  ('liuzzi', 'Red Bull', Decimal('2247036'), Decimal('70219.875000000000')),
#  ('garde', 'Caterham', Decimal('3592830'), Decimal('70447.647058823529')),
#  ('maldonado', 'Lotus F1', Decimal('64867286'), Decimal('72802.790123456790')),
#  ('maldonado', 'Williams', Decimal('123837546'), Decimal('72802.790123456790')),
#  ('kobayashi', 'Caterham', Decimal('3726970'), Decimal('74539.400000000000')),
#  ('kobayashi', 'Sauber', Decimal('104355160'), Decimal('74539.400000000000')),
#  ('kobayashi', 'Toyota', Decimal('7453940'), Decimal('74539.400000000000')),
#  ('vergne', 'Toro Rosso', Decimal('116165588'), Decimal('75432.200000000000')),
#  ('sutil', 'Sauber', Decimal('8382906'), Decimal('82185.352941176471')),
#  ('sutil', 'Spyker', Decimal('4191453'), Decimal('82185.352941176471')),
#  ('sutil', 'Force India', Decimal('138317949'), Decimal('82185.352941176471')),
#  ('jules_bianchi', 'Marussia', Decimal('8820603'), Decimal('91881.281250000000')),
#  ('chilton', 'Marussia', Decimal('12848932'), Decimal('97340.393939393939')),
#  ('raikkonen', 'Ferrari', Decimal('920149684'), Decimal('98055.166666666667')),
#  ('raikkonen', 'McLaren', Decimal('520084604'), Decimal('98055.166666666667')),
#  ('raikkonen', 'Lotus F1', Decimal('330053691'), Decimal('98055.166666666667')),
#  ('raikkonen', 'Sauber', Decimal('50008135'), Decimal('98055.166666666667')),
#  ('grosjean', 'Haas F1 Team', Decimal('106755781'), Decimal('100052.278350515464')),
#  ('grosjean', 'Lotus F1', Decimal('320267343'), Decimal('100052.278350515464')),
#  ('grosjean', 'Renault', Decimal('9705071'), Decimal('100052.278350515464')),
#  ('button', 'Brawn', Decimal('188811408'), Decimal('106312.729729729730')),
#  ('button', 'Benetton', Decimal('23601426'), Decimal('106312.729729729730')),
#  ('button', 'Honda', Decimal('224213547'), Decimal('106312.729729729730')),
#  ('button', 'Renault', Decimal('70804278'), Decimal('106312.729729729730')),
#  ('button', 'BAR', Decimal('318619251'), Decimal('106312.729729729730')),
#  ('button', 'McLaren', Decimal('1026662031'), Decimal('106312.729729729730')),
#  ('button', 'Williams', Decimal('47202852'), Decimal('106312.729729729730')),
#  ('alonso', 'Ferrari', Decimal('1150974156'), Decimal('108439.245901639344')),
#  ('alonso', 'Renault', Decimal('1058367040'), Decimal('108439.245901639344')),
#  ('alonso', 'McLaren', Decimal('383658052'), Decimal('108439.245901639344')),
#  ('rosberg', 'Williams', Decimal('446054832'), Decimal('111625.333333333333')),
#  ('rosberg', 'Mercedes', Decimal('1350554908'), Decimal('111625.333333333333')),
#  ('ericsson', 'Sauber', Decimal('50518993'), Decimal('112765.609375000000')),
#  ('ericsson', 'Caterham', Decimal('7216999'), Decimal('112765.609375000000')),
#  ('hamilton', 'McLaren', Decimal('1219183224'), Decimal('114284.141732283465')),
#  ('hamilton', 'Mercedes', Decimal('1233697310'), Decimal('114284.141732283465')),
#  ('vettel', 'BMW Sauber', Decimal('14419238'), Decimal('115353.904000000000')),
#  ('vettel', 'Toro Rosso', Decimal('173030856'), Decimal('115353.904000000000')),
#  ('vettel', 'Red Bull', Decimal('1398666086'), Decimal('115353.904000000000')),
#  ('vettel', 'Ferrari', Decimal('692123424'), Decimal('115353.904000000000')),
#  ('perez', 'Force India', Decimal('551153596'), Decimal('116968.080645161290')),
#  ('perez', 'Sauber', Decimal('217560630'), Decimal('116968.080645161290')),
#  ('perez', 'McLaren', Decimal('203056588'), Decimal('116968.080645161290')),
#  ('massa', 'Ferrari', Decimal('1708078064'), Decimal('121037.277777777778')),
#  ('massa', 'Williams', Decimal('625278577'), Decimal('121037.277777777778')),
#  ('massa', 'Sauber', Decimal('198259061'), Decimal('121037.277777777778')),
#  ('jolyon_palmer', 'Renault', Decimal('21507378'), Decimal('123605.620689655172')),
#  ('ricciardo', 'Red Bull', Decimal('863136792'), Decimal('127381.462809917355')),
#  ('ricciardo', 'Toro Rosso', Decimal('339089454'), Decimal('127381.462809917355')),
#  ('hulkenberg', 'Renault', Decimal('66742125'), Decimal('129596.359223300971')),
#  ('hulkenberg', 'Sauber', Decimal('173529525'), Decimal('129596.359223300971')),
#  ('hulkenberg', 'Force India', Decimal('654072825'), Decimal('129596.359223300971')),
#  ('hulkenberg', 'Williams', Decimal('93438975'), Decimal('129596.359223300971')),
#  ('stroll', 'Williams', Decimal('7560068'), Decimal('135001.214285714286')),
#  ('bottas', 'Mercedes', Decimal('176270192'), Decimal('138359.648351648352')),
#  ('bottas', 'Williams', Decimal('654717856'), Decimal('138359.648351648352')),
#  ('kvyat', 'Red Bull', Decimal('84509019'), Decimal('140147.626865671642')),
#  ('kvyat', 'Toro Rosso', Decimal('103288801'), Decimal('140147.626865671642')),
#  ('vandoorne', 'McLaren', Decimal('6065013'), Decimal('144405.071428571429')),
#  ('gutierrez', 'Sauber', Decimal('96698316'), Decimal('156977.785714285714')),
#  ('gutierrez', 'Haas F1 Team', Decimal('17581512'), Decimal('156977.785714285714')),
#  ('sainz', 'Toro Rosso', Decimal('150423732'), Decimal('167137.480000000000')),
#  ('max_verstappen', 'Toro Rosso', Decimal('90212364'), Decimal('170856.750000000000')),
#  ('max_verstappen', 'Red Bull', Decimal('180424728'), Decimal('170856.750000000000')),
#  ('kevin_magnussen', 'McLaren', Decimal('116668440'), Decimal('186968.653846153846')),
#  ('kevin_magnussen', 'Haas F1 Team', Decimal('29167110'), Decimal('186968.653846153846')),
#  ('kevin_magnussen', 'Renault', Decimal('29167110'), Decimal('186968.653846153846')),
#  ('nasr', 'Sauber', Decimal('76621797'), Decimal('218295.717948717949')),
#  ('wehrlein', 'Sauber', Decimal('7670219'), Decimal('247426.419354838710')),
#  ('wehrlein', 'Manor Marussia', Decimal('7670219'), Decimal('247426.419354838710')),
#  ('ocon', 'Manor Marussia', Decimal('7136690'), Decimal('297362.083333333333')),
#  ('ocon', 'Force India', Decimal('57093520'), Decimal('297362.083333333333'))]

# %% [markdown]
# This result might unfortunately also be wrong, considering that the count from before most likely was wrong.
